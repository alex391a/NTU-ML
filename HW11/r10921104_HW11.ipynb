# %% [markdown]
# # Homework 11 - Transfer Learning (Domain Adversarial Training)
#
# > Author: Arvin Liu (r09922071@ntu.edu.tw)
#
# If there are any questions, please contact mlta-2022-spring@googlegroups.com

# %% [markdown]
# # Readme
#
# In homework 11, you will need to implement Domain Adversarial Training in Transfer Learning. As shown in the bottom left part of the figure.
#
# <img src="https://i.imgur.com/iMVIxCH.png" width="500px">
#
# >
#
# ## Scenario and Why Domain Adversarial Training
# Now we have labeled source data and unlabeled target data, where source data might be relavent to the target data. We now want to train a model with source data only and test it on target data.
#
# What problem might occur if we do so? After we have learned Anomaly Detection, we now know that if we test the model with an abnormal data that have never appeared in source data, our trained model is likely to result in poor performance since it is not familiar with the abnormal data.
#
# For example, we have a model that contains Feature Extractor and Classifier:
# <img src="https://i.imgur.com/IL0PxCY.png" width="500px">
#
# When the model is trained with source data, the feature extractor
# will extract meaningful features since it is familiar with the distribution of it.It could be seen in the following figure that the blue dots, which is the distribution of source data, has already been clustered into different clusters. Therefore, the Classifier can predict the label based on these clusters.
#
# However, when test on the target data, the Feature Extractor will not be able to extract meaningful features that follow the distribution of the source feature distribution, which result in the classifier learned for the source domain will not be able to apply to the target domain.
#
#
# ## Domain Adversarial Training of Nerural Networks (DaNN)
#
# Based on the above problems, DaNN approaches build mappings between the source (training-time) and the target (test-time) domains, so that the classifier learned for the source domain can also be applied to the target domain, when composed with the learned mapping between domains.
#
# <img src="https://i.imgur.com/vrOE5a6.png" width="500px">
#
# In DaNN, the authors added a Domain Classifier, which is a deep discriminatively-trained classifeir in the training framework to distinguish the data from different domain by the features extracted by the feature extractor. As the training progresses, the approach promotes a domain classifier that discriminates between the source and the target domains and a feature extractor that can extractor features that are discriminative for the main learning task on the source domain and indiscriminate with respect to the shift between the domains.
#
#
# The feature extractor are likely to outperform the domain classifier as its input are generated by the feature extractor and that the task of domain classification and label classification are not conflict.
#
# This method leads to the emergence of features that are domain-invariant and on the same feature distribution.

# %% [markdown]
# # Data Introduce
#
# Our task contains source data: real photos, and target data: hand-drawn graffiti.
#
# We are going to train the model with the photos and the labels, and try to predict what the labels are for hand-drawn graffiti.
#
# The data could be downloaded [here](https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip). The code below is for data downloading and visualization.
#
# Note that: **The source and target data are all balanced data, you can make use of this information.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download dataset
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip" -O real_or_drawing.zip

# Download from mirrored dataset link
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.1/real_or_drawing.zip" -O real_or_drawing.zip
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.2/real_or_drawing.zip" -O real_or_drawing.zip

# Unzip the files
# !unzip real_or_drawing.zip
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: real_or_drawing/train_data/0/106.bmp
#   inflating: real_or_drawing/train_data/0/107.bmp
#   inflating: real_or_drawing/train_data/0/108.bmp
#   inflating: real_or_drawing/train_data/0/109.bmp
#   inflating: real_or_drawing/train_data/0/11.bmp
#   inflating: real_or_drawing/train_data/0/110.bmp
#   inflating: real_or_drawing/train_data/0/111.bmp
#   inflating: real_or_drawing/train_data/0/112.bmp
#   inflating: real_or_drawing/train_data/0/113.bmp
#   inflating: real_or_drawing/train_data/0/114.bmp
#   inflating: real_or_drawing/train_data/0/115.bmp
#   inflating: real_or_drawing/train_data/0/116.bmp
#   inflating: real_or_drawing/train_data/0/117.bmp
#   inflating: real_or_drawing/train_data/0/118.bmp
#   inflating: real_or_drawing/train_data/0/119.bmp
#   inflating: real_or_drawing/train_data/0/12.bmp
#   inflating: real_or_drawing/train_data/0/120.bmp
#   inflating: real_or_drawing/train_data/0/121.bmp
#   inflating: real_or_drawing/train_data/0/122.bmp
#   inflating: real_or_drawing/train_data/0/123.bmp
#   inflating: real_or_drawing/train_data/0/124.bmp
#   inflating: real_or_drawing/train_data/0/125.bmp
#   inflating: real_or_drawing/train_data/0/126.bmp
#   inflating: real_or_drawing/train_data/0/127.bmp
#   inflating: real_or_drawing/train_data/0/128.bmp
#   inflating: real_or_drawing/train_data/0/129.bmp
#   inflating: real_or_drawing/train_data/0/13.bmp
#   inflating: real_or_drawing/train_data/0/130.bmp
#   inflating: real_or_drawing/train_data/0/131.bmp
#   inflating: real_or_drawing/train_data/0/132.bmp
#   inflating: real_or_drawing/train_data/0/133.bmp
#   inflating: real_or_drawing/train_data/0/134.bmp
#   inflating: real_or_drawing/train_data/0/135.bmp
#   inflating: real_or_drawing/train_data/0/136.bmp
#   inflating: real_or_drawing/train_data/0/137.bmp
#   inflating: real_or_drawing/train_data/0/138.bmp
#   inflating: real_or_drawing/train_data/0/139.bmp
#   inflating: real_or_drawing/train_data/0/14.bmp
#   inflating: real_or_drawing/train_data/0/140.bmp
#   inflating: real_or_drawing/train_data/0/141.bmp
#   inflating: real_or_drawing/train_data/0/142.bmp
#   inflating: real_or_drawing/train_data/0/143.bmp
#   inflating: real_or_drawing/train_data/0/144.bmp
#   inflating: real_or_drawing/train_data/0/145.bmp
#   inflating: real_or_drawing/train_data/0/146.bmp
#   inflating: real_or_drawing/train_data/0/147.bmp
#   inflating: real_or_drawing/train_data/0/148.bmp
#   inflating: real_or_drawing/train_data/0/149.bmp
#   inflating: real_or_drawing/train_data/0/15.bmp
#   inflating: real_or_drawing/train_data/0/150.bmp
#   inflating: real_or_drawing/train_data/0/151.bmp
#   inflating: real_or_drawing/train_data/0/152.bmp
#   inflating: real_or_drawing/train_data/0/153.bmp
#   inflating: real_or_drawing/train_data/0/154.bmp
#   inflating: real_or_drawing/train_data/0/155.bmp
#   inflating: real_or_drawing/train_data/0/156.bmp
#   inflating: real_or_drawing/train_data/0/157.bmp
#   inflating: real_or_drawing/train_data/0/158.bmp
#   inflating: real_or_drawing/train_data/0/159.bmp
#   inflating: real_or_drawing/train_data/0/16.bmp
#   inflating: real_or_drawing/train_data/0/160.bmp
#   inflating: real_or_drawing/train_data/0/161.bmp
#   inflating: real_or_drawing/train_data/0/162.bmp
#   inflating: real_or_drawing/train_data/0/163.bmp
#   inflating: real_or_drawing/train_data/0/164.bmp
#   inflating: real_or_drawing/train_data/0/165.bmp
#   inflating: real_or_drawing/train_data/0/166.bmp
#   inflating: real_or_drawing/train_data/0/167.bmp
#   inflating: real_or_drawing/train_data/0/168.bmp
#   inflating: real_or_drawing/train_data/0/169.bmp
#   inflating: real_or_drawing/train_data/0/17.bmp
#   inflating: real_or_drawing/train_data/0/170.bmp
#   inflating: real_or_drawing/train_data/0/171.bmp
#   inflating: real_or_drawing/train_data/0/172.bmp
#   inflating: real_or_drawing/train_data/0/173.bmp
#   inflating: real_or_drawing/train_data/0/174.bmp
#   inflating: real_or_drawing/train_data/0/175.bmp
#   inflating: real_or_drawing/train_data/0/176.bmp
#   inflating: real_or_drawing/train_data/0/177.bmp
#   inflating: real_or_drawing/train_data/0/178.bmp
#   inflating: real_or_drawing/train_data/0/179.bmp
#   inflating: real_or_drawing/train_data/0/18.bmp
#   inflating: real_or_drawing/train_data/0/180.bmp
#   inflating: real_or_drawing/train_data/0/181.bmp
#   inflating: real_or_drawing/train_data/0/182.bmp
#   inflating: real_or_drawing/train_data/0/183.bmp
#   inflating: real_or_drawing/train_data/0/184.bmp
#   inflating: real_or_drawing/train_data/0/185.bmp
#   inflating: real_or_drawing/train_data/0/186.bmp
#   inflating: real_or_drawing/train_data/0/187.bmp
#   inflating: real_or_drawing/train_data/0/188.bmp
#   inflating: real_or_drawing/train_data/0/189.bmp
#   inflating: real_or_drawing/train_data/0/19.bmp
#   inflating: real_or_drawing/train_data/0/190.bmp
#   inflating: real_or_drawing/train_data/0/191.bmp
#   inflating: real_or_drawing/train_data/0/192.bmp
#   inflating: real_or_drawing/train_data/0/193.bmp
#   inflating: real_or_drawing/train_data/0/194.bmp
#   inflating: real_or_drawing/train_data/0/195.bmp
#   inflating: real_or_drawing/train_data/0/196.bmp
#   inflating: real_or_drawing/train_data/0/197.bmp
#   inflating: real_or_drawing/train_data/0/198.bmp
#   inflating: real_or_drawing/train_data/0/199.bmp
#   inflating: real_or_drawing/train_data/0/2.bmp
#   inflating: real_or_drawing/train_data/0/20.bmp
#   inflating: real_or_drawing/train_data/0/200.bmp
#   inflating: real_or_drawing/train_data/0/201.bmp
#   inflating: real_or_drawing/train_data/0/202.bmp
#   inflating: real_or_drawing/train_data/0/203.bmp
#   inflating: real_or_drawing/train_data/0/204.bmp
#   inflating: real_or_drawing/train_data/0/205.bmp
#   inflating: real_or_drawing/train_data/0/206.bmp
#   inflating: real_or_drawing/train_data/0/207.bmp
#   inflating: real_or_drawing/train_data/0/208.bmp
#   inflating: real_or_drawing/train_data/0/209.bmp
#   inflating: real_or_drawing/train_data/0/21.bmp
#   inflating: real_or_drawing/train_data/0/210.bmp
#   inflating: real_or_drawing/train_data/0/211.bmp
#   inflating: real_or_drawing/train_data/0/212.bmp
#   inflating: real_or_drawing/train_data/0/213.bmp
#   inflating: real_or_drawing/train_data/0/214.bmp
#   inflating: real_or_drawing/train_data/0/215.bmp
#   inflating: real_or_drawing/train_data/0/216.bmp
#   inflating: real_or_drawing/train_data/0/217.bmp
#   inflating: real_or_drawing/train_data/0/218.bmp
#   inflating: real_or_drawing/train_data/0/219.bmp
#   inflating: real_or_drawing/train_data/0/22.bmp
#   inflating: real_or_drawing/train_data/0/220.bmp
#   inflating: real_or_drawing/train_data/0/221.bmp
#   inflating: real_or_drawing/train_data/0/222.bmp
#   inflating: real_or_drawing/train_data/0/223.bmp
#   inflating: real_or_drawing/train_data/0/224.bmp
#   inflating: real_or_drawing/train_data/0/225.bmp
#   inflating: real_or_drawing/train_data/0/226.bmp
#   inflating: real_or_drawing/train_data/0/227.bmp
#   inflating: real_or_drawing/train_data/0/228.bmp
#   inflating: real_or_drawing/train_data/0/229.bmp
#   inflating: real_or_drawing/train_data/0/23.bmp
#   inflating: real_or_drawing/train_data/0/230.bmp
#   inflating: real_or_drawing/train_data/0/231.bmp
#   inflating: real_or_drawing/train_data/0/232.bmp
#   inflating: real_or_drawing/train_data/0/233.bmp
#   inflating: real_or_drawing/train_data/0/234.bmp
#   inflating: real_or_drawing/train_data/0/235.bmp
#   inflating: real_or_drawing/train_data/0/236.bmp
#   inflating: real_or_drawing/train_data/0/237.bmp
#   inflating: real_or_drawing/train_data/0/238.bmp
#   inflating: real_or_drawing/train_data/0/239.bmp
#   inflating: real_or_drawing/train_data/0/24.bmp
#   inflating: real_or_drawing/train_data/0/240.bmp
#   inflating: real_or_drawing/train_data/0/241.bmp
#   inflating: real_or_drawing/train_data/0/242.bmp
#   inflating: real_or_drawing/train_data/0/243.bmp
#   inflating: real_or_drawing/train_data/0/244.bmp
#   inflating: real_or_drawing/train_data/0/245.bmp
#   inflating: real_or_drawing/train_data/0/246.bmp
#   inflating: real_or_drawing/train_data/0/247.bmp
#   inflating: real_or_drawing/train_data/0/248.bmp
#   inflating: real_or_drawing/train_data/0/249.bmp
#   inflating: real_or_drawing/train_data/0/25.bmp
#   inflating: real_or_drawing/train_data/0/250.bmp
#   inflating: real_or_drawing/train_data/0/251.bmp
#   inflating: real_or_drawing/train_data/0/252.bmp
#   inflating: real_or_drawing/train_data/0/253.bmp
#   inflating: real_or_drawing/train_data/0/254.bmp
#   inflating: real_or_drawing/train_data/0/255.bmp
#   inflating: real_or_drawing/train_data/0/256.bmp
#   inflating: real_or_drawing/train_data/0/257.bmp
#   inflating: real_or_drawing/train_data/0/258.bmp
#   inflating: real_or_drawing/train_data/0/259.bmp
#   inflating: real_or_drawing/train_data/0/26.bmp
#   inflating: real_or_drawing/train_data/0/260.bmp
#   inflating: real_or_drawing/train_data/0/261.bmp
#   inflating: real_or_drawing/train_data/0/262.bmp
#   inflating: real_or_drawing/train_data/0/263.bmp
#   inflating: real_or_drawing/train_data/0/264.bmp
#   inflating: real_or_drawing/train_data/0/265.bmp
#   inflating: real_or_drawing/train_data/0/266.bmp
#   inflating: real_or_drawing/train_data/0/267.bmp
#   inflating: real_or_drawing/train_data/0/268.bmp
#   inflating: real_or_drawing/train_data/0/269.bmp
#   inflating: real_or_drawing/train_data/0/27.bmp
#   inflating: real_or_drawing/train_data/0/270.bmp
#   inflating: real_or_drawing/train_data/0/271.bmp
#   inflating: real_or_drawing/train_data/0/272.bmp
#   inflating: real_or_drawing/train_data/0/273.bmp
#   inflating: real_or_drawing/train_data/0/274.bmp
#   inflating: real_or_drawing/train_data/0/275.bmp
#   inflating: real_or_drawing/train_data/0/276.bmp
#   inflating: real_or_drawing/train_data/0/277.bmp
#   inflating: real_or_drawing/train_data/0/278.bmp
#   inflating: real_or_drawing/train_data/0/279.bmp
#   inflating: real_or_drawing/train_data/0/28.bmp
#   inflating: real_or_drawing/train_data/0/280.bmp
#   inflating: real_or_drawing/train_data/0/281.bmp
#   inflating: real_or_drawing/train_data/0/282.bmp
#   inflating: real_or_drawing/train_data/0/283.bmp
#   inflating: real_or_drawing/train_data/0/284.bmp
#   inflating: real_or_drawing/train_data/0/285.bmp
#   inflating: real_or_drawing/train_data/0/286.bmp
#   inflating: real_or_drawing/train_data/0/287.bmp
#   inflating: real_or_drawing/train_data/0/288.bmp
#   inflating: real_or_drawing/train_data/0/289.bmp
#   inflating: real_or_drawing/train_data/0/29.bmp
#   inflating: real_or_drawing/train_data/0/290.bmp
#   inflating: real_or_drawing/train_data/0/291.bmp
#   inflating: real_or_drawing/train_data/0/292.bmp
#   inflating: real_or_drawing/train_data/0/293.bmp
#   inflating: real_or_drawing/train_data/0/294.bmp
#   inflating: real_or_drawing/train_data/0/295.bmp
#   inflating: real_or_drawing/train_data/0/296.bmp
#   inflating: real_or_drawing/train_data/0/297.bmp
#   inflating: real_or_drawing/train_data/0/298.bmp
#   inflating: real_or_drawing/train_data/0/299.bmp
#   inflating: real_or_drawing/train_data/0/3.bmp
#   inflating: real_or_drawing/train_data/0/30.bmp
#   inflating: real_or_drawing/train_data/0/300.bmp
#   inflating: real_or_drawing/train_data/0/301.bmp
#   inflating: real_or_drawing/train_data/0/302.bmp
#   inflating: real_or_drawing/train_data/0/303.bmp
#   inflating: real_or_drawing/train_data/0/304.bmp
#   inflating: real_or_drawing/train_data/0/305.bmp
#   inflating: real_or_drawing/train_data/0/306.bmp
#   inflating: real_or_drawing/train_data/0/307.bmp
#   inflating: real_or_drawing/train_data/0/308.bmp
#   inflating: real_or_drawing/train_data/0/309.bmp
#   inflating: real_or_drawing/train_data/0/31.bmp
#   inflating: real_or_drawing/train_data/0/310.bmp
#   inflating: real_or_drawing/train_data/0/311.bmp
#   inflating: real_or_drawing/train_data/0/312.bmp
#   inflating: real_or_drawing/train_data/0/313.bmp
#   inflating: real_or_drawing/train_data/0/314.bmp
#   inflating: real_or_drawing/train_data/0/315.bmp
#   inflating: real_or_drawing/train_data/0/316.bmp
#   inflating: real_or_drawing/train_data/0/317.bmp
#   inflating: real_or_drawing/train_data/0/318.bmp
#   inflating: real_or_drawing/train_data/0/319.bmp
#   inflating: real_or_drawing/train_data/0/32.bmp
#   inflating: real_or_drawing/train_data/0/320.bmp
#   inflating: real_or_drawing/train_data/0/321.bmp
#   inflating: real_or_drawing/train_data/0/322.bmp
#   inflating: real_or_drawing/train_data/0/323.bmp
#   inflating: real_or_drawing/train_data/0/324.bmp
#   inflating: real_or_drawing/train_data/0/325.bmp
#   inflating: real_or_drawing/train_data/0/326.bmp
#   inflating: real_or_drawing/train_data/0/327.bmp
#   inflating: real_or_drawing/train_data/0/328.bmp
#   inflating: real_or_drawing/train_data/0/329.bmp
#   inflating: real_or_drawing/train_data/0/33.bmp
#   inflating: real_or_drawing/train_data/0/330.bmp
#   inflating: real_or_drawing/train_data/0/331.bmp
#   inflating: real_or_drawing/train_data/0/332.bmp
#   inflating: real_or_drawing/train_data/0/333.bmp
#   inflating: real_or_drawing/train_data/0/334.bmp
#   inflating: real_or_drawing/train_data/0/335.bmp
#   inflating: real_or_drawing/train_data/0/336.bmp
#   inflating: real_or_drawing/train_data/0/337.bmp
#   inflating: real_or_drawing/train_data/0/338.bmp
#   inflating: real_or_drawing/train_data/0/339.bmp
#   inflating: real_or_drawing/train_data/0/34.bmp
#   inflating: real_or_drawing/train_data/0/340.bmp
#   inflating: real_or_drawing/train_data/0/341.bmp
#   inflating: real_or_drawing/train_data/0/342.bmp
#   inflating: real_or_drawing/train_data/0/343.bmp
#   inflating: real_or_drawing/train_data/0/344.bmp
#   inflating: real_or_drawing/train_data/0/345.bmp
#   inflating: real_or_drawing/train_data/0/346.bmp
#   inflating: real_or_drawing/train_data/0/347.bmp
#   inflating: real_or_drawing/train_data/0/348.bmp
#   inflating: real_or_drawing/train_data/0/349.bmp
#   inflating: real_or_drawing/train_data/0/35.bmp
#   inflating: real_or_drawing/train_data/0/350.bmp
#   inflating: real_or_drawing/train_data/0/351.bmp
#   inflating: real_or_drawing/train_data/0/352.bmp
#   inflating: real_or_drawing/train_data/0/353.bmp
#   inflating: real_or_drawing/train_data/0/354.bmp
#   inflating: real_or_drawing/train_data/0/355.bmp
#   inflating: real_or_drawing/train_data/0/356.bmp
#   inflating: real_or_drawing/train_data/0/357.bmp
#   inflating: real_or_drawing/train_data/0/358.bmp
#   inflating: real_or_drawing/train_data/0/359.bmp
#   inflating: real_or_drawing/train_data/0/36.bmp
#   inflating: real_or_drawing/train_data/0/360.bmp
#   inflating: real_or_drawing/train_data/0/361.bmp
#   inflating: real_or_drawing/train_data/0/362.bmp
#   inflating: real_or_drawing/train_data/0/363.bmp
#   inflating: real_or_drawing/train_data/0/364.bmp
#   inflating: real_or_drawing/train_data/0/365.bmp
#   inflating: real_or_drawing/train_data/0/366.bmp
#   inflating: real_or_drawing/train_data/0/367.bmp
#   inflating: real_or_drawing/train_data/0/368.bmp
#   inflating: real_or_drawing/train_data/0/369.bmp
#   inflating: real_or_drawing/train_data/0/37.bmp
#   inflating: real_or_drawing/train_data/0/370.bmp
#   inflating: real_or_drawing/train_data/0/371.bmp
#   inflating: real_or_drawing/train_data/0/372.bmp
#   inflating: real_or_drawing/train_data/0/373.bmp
#   inflating: real_or_drawing/train_data/0/374.bmp
#   inflating: real_or_drawing/train_data/0/375.bmp
#   inflating: real_or_drawing/train_data/0/376.bmp
#   inflating: real_or_drawing/train_data/0/377.bmp
#   inflating: real_or_drawing/train_data/0/378.bmp
#   inflating: real_or_drawing/train_data/0/379.bmp
#   inflating: real_or_drawing/train_data/0/38.bmp
#   inflating: real_or_drawing/train_data/0/380.bmp
#   inflating: real_or_drawing/train_data/0/381.bmp
#   inflating: real_or_drawing/train_data/0/382.bmp
#   inflating: real_or_drawing/train_data/0/383.bmp
#   inflating: real_or_drawing/train_data/0/384.bmp
#   inflating: real_or_drawing/train_data/0/385.bmp
#   inflating: real_or_drawing/train_data/0/386.bmp
#   inflating: real_or_drawing/train_data/0/387.bmp
#   inflating: real_or_drawing/train_data/0/388.bmp
#   inflating: real_or_drawing/train_data/0/389.bmp
#   inflating: real_or_drawing/train_data/0/39.bmp
#   inflating: real_or_drawing/train_data/0/390.bmp
#   inflating: real_or_drawing/train_data/0/391.bmp
#   inflating: real_or_drawing/train_data/0/392.bmp
#   inflating: real_or_drawing/train_data/0/393.bmp
#   inflating: real_or_drawing/train_data/0/394.bmp
#   inflating: real_or_drawing/train_data/0/395.bmp
#   inflating: real_or_drawing/train_data/0/396.bmp
#   inflating: real_or_drawing/train_data/0/397.bmp
#   inflating: real_or_drawing/train_data/0/398.bmp
#   inflating: real_or_drawing/train_data/0/399.bmp
#   inflating: real_or_drawing/train_data/0/4.bmp
#   inflating: real_or_drawing/train_data/0/40.bmp
#   inflating: real_or_drawing/train_data/0/400.bmp
#   inflating: real_or_drawing/train_data/0/401.bmp
#   inflating: real_or_drawing/train_data/0/402.bmp
#   inflating: real_or_drawing/train_data/0/403.bmp
#   inflating: real_or_drawing/train_data/0/404.bmp
#   inflating: real_or_drawing/train_data/0/405.bmp
#   inflating: real_or_drawing/train_data/0/406.bmp
#   inflating: real_or_drawing/train_data/0/407.bmp
#   inflating: real_or_drawing/train_data/0/408.bmp
#   inflating: real_or_drawing/train_data/0/409.bmp
#   inflating: real_or_drawing/train_data/0/41.bmp
#   inflating: real_or_drawing/train_data/0/410.bmp
#   inflating: real_or_drawing/train_data/0/411.bmp
#   inflating: real_or_drawing/train_data/0/412.bmp
#   inflating: real_or_drawing/train_data/0/413.bmp
#   inflating: real_or_drawing/train_data/0/414.bmp
#   inflating: real_or_drawing/train_data/0/415.bmp
#   inflating: real_or_drawing/train_data/0/416.bmp
#   inflating: real_or_drawing/train_data/0/417.bmp
#   inflating: real_or_drawing/train_data/0/418.bmp
#   inflating: real_or_drawing/train_data/0/419.bmp
#   inflating: real_or_drawing/train_data/0/42.bmp
#   inflating: real_or_drawing/train_data/0/420.bmp
#   inflating: real_or_drawing/train_data/0/421.bmp
#   inflating: real_or_drawing/train_data/0/422.bmp
#   inflating: real_or_drawing/train_data/0/423.bmp
#   inflating: real_or_drawing/train_data/0/424.bmp
#   inflating: real_or_drawing/train_data/0/425.bmp
#   inflating: real_or_drawing/train_data/0/426.bmp
#   inflating: real_or_drawing/train_data/0/427.bmp
#   inflating: real_or_drawing/train_data/0/428.bmp
#   inflating: real_or_drawing/train_data/0/429.bmp
#   inflating: real_or_drawing/train_data/0/43.bmp
#   inflating: real_or_drawing/train_data/0/430.bmp
#   inflating: real_or_drawing/train_data/0/431.bmp
#   inflating: real_or_drawing/train_data/0/432.bmp
#   inflating: real_or_drawing/train_data/0/433.bmp
#   inflating: real_or_drawing/train_data/0/434.bmp
#   inflating: real_or_drawing/train_data/0/435.bmp
#   inflating: real_or_drawing/train_data/0/436.bmp
#   inflating: real_or_drawing/train_data/0/437.bmp
#   inflating: real_or_drawing/train_data/0/438.bmp
#   inflating: real_or_drawing/train_data/0/439.bmp
#   inflating: real_or_drawing/train_data/0/44.bmp
#   inflating: real_or_drawing/train_data/0/440.bmp
#   inflating: real_or_drawing/train_data/0/441.bmp
#   inflating: real_or_drawing/train_data/0/442.bmp
#   inflating: real_or_drawing/train_data/0/443.bmp
#   inflating: real_or_drawing/train_data/0/444.bmp
#   inflating: real_or_drawing/train_data/0/445.bmp
#   inflating: real_or_drawing/train_data/0/446.bmp
#   inflating: real_or_drawing/train_data/0/447.bmp
#   inflating: real_or_drawing/train_data/0/448.bmp
#   inflating: real_or_drawing/train_data/0/449.bmp
#   inflating: real_or_drawing/train_data/0/45.bmp
#   inflating: real_or_drawing/train_data/0/450.bmp
#   inflating: real_or_drawing/train_data/0/451.bmp
#   inflating: real_or_drawing/train_data/0/452.bmp
#   inflating: real_or_drawing/train_data/0/453.bmp
#   inflating: real_or_drawing/train_data/0/454.bmp
#   inflating: real_or_drawing/train_data/0/455.bmp
#   inflating: real_or_drawing/train_data/0/456.bmp
#   inflating: real_or_drawing/train_data/0/457.bmp
#   inflating: real_or_drawing/train_data/0/458.bmp
#   inflating: real_or_drawing/train_data/0/459.bmp
#   inflating: real_or_drawing/train_data/0/46.bmp
#   inflating: real_or_drawing/train_data/0/460.bmp
#   inflating: real_or_drawing/train_data/0/461.bmp
#   inflating: real_or_drawing/train_data/0/462.bmp
#   inflating: real_or_drawing/train_data/0/463.bmp
#   inflating: real_or_drawing/train_data/0/464.bmp
#   inflating: real_or_drawing/train_data/0/465.bmp
#   inflating: real_or_drawing/train_data/0/466.bmp
#   inflating: real_or_drawing/train_data/0/467.bmp
#   inflating: real_or_drawing/train_data/0/468.bmp
#   inflating: real_or_drawing/train_data/0/469.bmp
#   inflating: real_or_drawing/train_data/0/47.bmp
#   inflating: real_or_drawing/train_data/0/470.bmp
#   inflating: real_or_drawing/train_data/0/471.bmp
#   inflating: real_or_drawing/train_data/0/472.bmp
#   inflating: real_or_drawing/train_data/0/473.bmp
#   inflating: real_or_drawing/train_data/0/474.bmp
#   inflating: real_or_drawing/train_data/0/475.bmp
#   inflating: real_or_drawing/train_data/0/476.bmp
#   inflating: real_or_drawing/train_data/0/477.bmp
#   inflating: real_or_drawing/train_data/0/478.bmp
#   inflating: real_or_drawing/train_data/0/479.bmp
#   inflating: real_or_drawing/train_data/0/48.bmp
#   inflating: real_or_drawing/train_data/0/480.bmp
#   inflating: real_or_drawing/train_data/0/481.bmp
#   inflating: real_or_drawing/train_data/0/482.bmp
#   inflating: real_or_drawing/train_data/0/483.bmp
#   inflating: real_or_drawing/train_data/0/484.bmp
#   inflating: real_or_drawing/train_data/0/485.bmp
#   inflating: real_or_drawing/train_data/0/486.bmp
#   inflating: real_or_drawing/train_data/0/487.bmp
#   inflating: real_or_drawing/train_data/0/488.bmp
#   inflating: real_or_drawing/train_data/0/489.bmp
#   inflating: real_or_drawing/train_data/0/49.bmp
#   inflating: real_or_drawing/train_data/0/490.bmp
#   inflating: real_or_drawing/train_data/0/491.bmp
#   inflating: real_or_drawing/train_data/0/492.bmp
#   inflating: real_or_drawing/train_data/0/493.bmp
#   inflating: real_or_drawing/train_data/0/494.bmp
#   inflating: real_or_drawing/train_data/0/495.bmp
#   inflating: real_or_drawing/train_data/0/496.bmp
#   inflating: real_or_drawing/train_data/0/497.bmp
#   inflating: real_or_drawing/train_data/0/498.bmp
#   inflating: real_or_drawing/train_data/0/499.bmp
#   inflating: real_or_drawing/train_data/0/5.bmp
#   inflating: real_or_drawing/train_data/0/50.bmp
#   inflating: real_or_drawing/train_data/0/51.bmp
#   inflating: real_or_drawing/train_data/0/52.bmp
#   inflating: real_or_drawing/train_data/0/53.bmp
#   inflating: real_or_drawing/train_data/0/54.bmp
#   inflating: real_or_drawing/train_data/0/55.bmp
#   inflating: real_or_drawing/train_data/0/56.bmp
#   inflating: real_or_drawing/train_data/0/57.bmp
#   inflating: real_or_drawing/train_data/0/58.bmp
#   inflating: real_or_drawing/train_data/0/59.bmp
#   inflating: real_or_drawing/train_data/0/6.bmp
#   inflating: real_or_drawing/train_data/0/60.bmp
#   inflating: real_or_drawing/train_data/0/61.bmp
#   inflating: real_or_drawing/train_data/0/62.bmp
#   inflating: real_or_drawing/train_data/0/63.bmp
#   inflating: real_or_drawing/train_data/0/64.bmp
#   inflating: real_or_drawing/train_data/0/65.bmp
#   inflating: real_or_drawing/train_data/0/66.bmp
#   inflating: real_or_drawing/train_data/0/67.bmp
#   inflating: real_or_drawing/train_data/0/68.bmp
#   inflating: real_or_drawing/train_data/0/69.bmp
#   inflating: real_or_drawing/train_data/0/7.bmp
#   inflating: real_or_drawing/train_data/0/70.bmp
#   inflating: real_or_drawing/train_data/0/71.bmp
#   inflating: real_or_drawing/train_data/0/72.bmp
#   inflating: real_or_drawing/train_data/0/73.bmp
#   inflating: real_or_drawing/train_data/0/74.bmp
#   inflating: real_or_drawing/train_data/0/75.bmp
#   inflating: real_or_drawing/train_data/0/76.bmp
#   inflating: real_or_drawing/train_data/0/77.bmp
#   inflating: real_or_drawing/train_data/0/78.bmp
#   inflating: real_or_drawing/train_data/0/79.bmp
#   inflating: real_or_drawing/train_data/0/8.bmp
#   inflating: real_or_drawing/train_data/0/80.bmp
#   inflating: real_or_drawing/train_data/0/81.bmp
#   inflating: real_or_drawing/train_data/0/82.bmp
#   inflating: real_or_drawing/train_data/0/83.bmp
#   inflating: real_or_drawing/train_data/0/84.bmp
#   inflating: real_or_drawing/train_data/0/85.bmp
#   inflating: real_or_drawing/train_data/0/86.bmp
#   inflating: real_or_drawing/train_data/0/87.bmp
#   inflating: real_or_drawing/train_data/0/88.bmp
#   inflating: real_or_drawing/train_data/0/89.bmp
#   inflating: real_or_drawing/train_data/0/9.bmp
#   inflating: real_or_drawing/train_data/0/90.bmp
#   inflating: real_or_drawing/train_data/0/91.bmp
#   inflating: real_or_drawing/train_data/0/92.bmp
#   inflating: real_or_drawing/train_data/0/93.bmp
#   inflating: real_or_drawing/train_data/0/94.bmp
#   inflating: real_or_drawing/train_data/0/95.bmp
#   inflating: real_or_drawing/train_data/0/96.bmp
#   inflating: real_or_drawing/train_data/0/97.bmp
#   inflating: real_or_drawing/train_data/0/98.bmp
#   inflating: real_or_drawing/train_data/0/99.bmp
#    creating: real_or_drawing/train_data/1/
#   inflating: real_or_drawing/train_data/1/500.bmp
#   inflating: real_or_drawing/train_data/1/501.bmp
#   inflating: real_or_drawing/train_data/1/502.bmp
#   inflating: real_or_drawing/train_data/1/503.bmp
#   inflating: real_or_drawing/train_data/1/504.bmp
#   inflating: real_or_drawing/train_data/1/505.bmp
#   inflating: real_or_drawing/train_data/1/506.bmp
#   inflating: real_or_drawing/train_data/1/507.bmp
#   inflating: real_or_drawing/train_data/1/508.bmp
#   inflating: real_or_drawing/train_data/1/509.bmp
#   inflating: real_or_drawing/train_data/1/510.bmp
#   inflating: real_or_drawing/train_data/1/511.bmp
#   inflating: real_or_drawing/train_data/1/512.bmp
#   inflating: real_or_drawing/train_data/1/513.bmp
#   inflating: real_or_drawing/train_data/1/514.bmp
#   inflating: real_or_drawing/train_data/1/515.bmp
#   inflating: real_or_drawing/train_data/1/516.bmp
#   inflating: real_or_drawing/train_data/1/517.bmp
#   inflating: real_or_drawing/train_data/1/518.bmp
#   inflating: real_or_drawing/train_data/1/519.bmp
#   inflating: real_or_drawing/train_data/1/520.bmp
#   inflating: real_or_drawing/train_data/1/521.bmp
#   inflating: real_or_drawing/train_data/1/522.bmp
#   inflating: real_or_drawing/train_data/1/523.bmp
#   inflating: real_or_drawing/train_data/1/524.bmp
#   inflating: real_or_drawing/train_data/1/525.bmp
#   inflating: real_or_drawing/train_data/1/526.bmp
#   inflating: real_or_drawing/train_data/1/527.bmp
#   inflating: real_or_drawing/train_data/1/528.bmp
#   inflating: real_or_drawing/train_data/1/529.bmp
#   inflating: real_or_drawing/train_data/1/530.bmp
#   inflating: real_or_drawing/train_data/1/531.bmp
#   inflating: real_or_drawing/train_data/1/532.bmp
#   inflating: real_or_drawing/train_data/1/533.bmp
#   inflating: real_or_drawing/train_data/1/534.bmp
#   inflating: real_or_drawing/train_data/1/535.bmp
#   inflating: real_or_drawing/train_data/1/536.bmp
#   inflating: real_or_drawing/train_data/1/537.bmp
#   inflating: real_or_drawing/train_data/1/538.bmp
#   inflating: real_or_drawing/train_data/1/539.bmp
#   inflating: real_or_drawing/train_data/1/540.bmp
#   inflating: real_or_drawing/train_data/1/541.bmp
#   inflating: real_or_drawing/train_data/1/542.bmp
#   inflating: real_or_drawing/train_data/1/543.bmp
#   inflating: real_or_drawing/train_data/1/544.bmp
#   inflating: real_or_drawing/train_data/1/545.bmp
#   inflating: real_or_drawing/train_data/1/546.bmp
#   inflating: real_or_drawing/train_data/1/547.bmp
#   inflating: real_or_drawing/train_data/1/548.bmp
#   inflating: real_or_drawing/train_data/1/549.bmp
#   inflating: real_or_drawing/train_data/1/550.bmp
#   inflating: real_or_drawing/train_data/1/551.bmp
#   inflating: real_or_drawing/train_data/1/552.bmp
#   inflating: real_or_drawing/train_data/1/553.bmp
#   inflating: real_or_drawing/train_data/1/554.bmp
#   inflating: real_or_drawing/train_data/1/555.bmp
#   inflating: real_or_drawing/train_data/1/556.bmp
#   inflating: real_or_drawing/train_data/1/557.bmp
#   inflating: real_or_drawing/train_data/1/558.bmp
#   inflating: real_or_drawing/train_data/1/559.bmp
#   inflating: real_or_drawing/train_data/1/560.bmp
#   inflating: real_or_drawing/train_data/1/561.bmp
#   inflating: real_or_drawing/train_data/1/562.bmp
#   inflating: real_or_drawing/train_data/1/563.bmp
#   inflating: real_or_drawing/train_data/1/564.bmp
#   inflating: real_or_drawing/train_data/1/565.bmp
#   inflating: real_or_drawing/train_data/1/566.bmp
#   inflating: real_or_drawing/train_data/1/567.bmp
#   inflating: real_or_drawing/train_data/1/568.bmp
#   inflating: real_or_drawing/train_data/1/569.bmp
#   inflating: real_or_drawing/train_data/1/570.bmp
#   inflating: real_or_drawing/train_data/1/571.bmp
#   inflating: real_or_drawing/train_data/1/572.bmp
#   inflating: real_or_drawing/train_data/1/573.bmp
#   inflating: real_or_drawing/train_data/1/574.bmp
#   inflating: real_or_drawing/train_data/1/575.bmp
#   inflating: real_or_drawing/train_data/1/576.bmp
#   inflating: real_or_drawing/train_data/1/577.bmp
#   inflating: real_or_drawing/train_data/1/578.bmp
#   inflating: real_or_drawing/train_data/1/579.bmp
#   inflating: real_or_drawing/train_data/1/580.bmp
#   inflating: real_or_drawing/train_data/1/581.bmp
#   inflating: real_or_drawing/train_data/1/582.bmp
#   inflating: real_or_drawing/train_data/1/583.bmp
#   inflating: real_or_drawing/train_data/1/584.bmp
#   inflating: real_or_drawing/train_data/1/585.bmp
#   inflating: real_or_drawing/train_data/1/586.bmp
#   inflating: real_or_drawing/train_data/1/587.bmp
#   inflating: real_or_drawing/train_data/1/588.bmp
#   inflating: real_or_drawing/train_data/1/589.bmp
#   inflating: real_or_drawing/train_data/1/590.bmp
#   inflating: real_or_drawing/train_data/1/591.bmp
#   inflating: real_or_drawing/train_data/1/592.bmp
#   inflating: real_or_drawing/train_data/1/593.bmp
#   inflating: real_or_drawing/train_data/1/594.bmp
#   inflating: real_or_drawing/train_data/1/595.bmp
#   inflating: real_or_drawing/train_data/1/596.bmp
#   inflating: real_or_drawing/train_data/1/597.bmp
#   inflating: real_or_drawing/train_data/1/598.bmp
#   inflating: real_or_drawing/train_data/1/599.bmp
#   inflating: real_or_drawing/train_data/1/600.bmp
#   inflating: real_or_drawing/train_data/1/601.bmp
#   inflating: real_or_drawing/train_data/1/602.bmp
#   inflating: real_or_drawing/train_data/1/603.bmp
#   inflating: real_or_drawing/train_data/1/604.bmp
#   inflating: real_or_drawing/train_data/1/605.bmp
#   inflating: real_or_drawing/train_data/1/606.bmp
#   inflating: real_or_drawing/train_data/1/607.bmp
#   inflating: real_or_drawing/train_data/1/608.bmp
#   inflating: real_or_drawing/train_data/1/609.bmp
#   inflating: real_or_drawing/train_data/1/610.bmp
#   inflating: real_or_drawing/train_data/1/611.bmp
#   inflating: real_or_drawing/train_data/1/612.bmp
#   inflating: real_or_drawing/train_data/1/613.bmp
#   inflating: real_or_drawing/train_data/1/614.bmp
#   inflating: real_or_drawing/train_data/1/615.bmp
#   inflating: real_or_drawing/train_data/1/616.bmp
#   inflating: real_or_drawing/train_data/1/617.bmp
#   inflating: real_or_drawing/train_data/1/618.bmp
#   inflating: real_or_drawing/train_data/1/619.bmp
#   inflating: real_or_drawing/train_data/1/620.bmp
#   inflating: real_or_drawing/train_data/1/621.bmp
#   inflating: real_or_drawing/train_data/1/622.bmp
#   inflating: real_or_drawing/train_data/1/623.bmp
#   inflating: real_or_drawing/train_data/1/624.bmp
#   inflating: real_or_drawing/train_data/1/625.bmp
#   inflating: real_or_drawing/train_data/1/626.bmp
#   inflating: real_or_drawing/train_data/1/627.bmp
#   inflating: real_or_drawing/train_data/1/628.bmp
#   inflating: real_or_drawing/train_data/1/629.bmp
#   inflating: real_or_drawing/train_data/1/630.bmp
#   inflating: real_or_drawing/train_data/1/631.bmp
#   inflating: real_or_drawing/train_data/1/632.bmp
#   inflating: real_or_drawing/train_data/1/633.bmp
#   inflating: real_or_drawing/train_data/1/634.bmp
#   inflating: real_or_drawing/train_data/1/635.bmp
#   inflating: real_or_drawing/train_data/1/636.bmp
#   inflating: real_or_drawing/train_data/1/637.bmp
#   inflating: real_or_drawing/train_data/1/638.bmp
#   inflating: real_or_drawing/train_data/1/639.bmp
#   inflating: real_or_drawing/train_data/1/640.bmp
#   inflating: real_or_drawing/train_data/1/641.bmp
#   inflating: real_or_drawing/train_data/1/642.bmp
#   inflating: real_or_drawing/train_data/1/643.bmp
#   inflating: real_or_drawing/train_data/1/644.bmp
#   inflating: real_or_drawing/train_data/1/645.bmp
#   inflating: real_or_drawing/train_data/1/646.bmp
#   inflating: real_or_drawing/train_data/1/647.bmp
#   inflating: real_or_drawing/train_data/1/648.bmp
#   inflating: real_or_drawing/train_data/1/649.bmp
#   inflating: real_or_drawing/train_data/1/650.bmp
#   inflating: real_or_drawing/train_data/1/651.bmp
#   inflating: real_or_drawing/train_data/1/652.bmp
#   inflating: real_or_drawing/train_data/1/653.bmp
#   inflating: real_or_drawing/train_data/1/654.bmp
#   inflating: real_or_drawing/train_data/1/655.bmp
#   inflating: real_or_drawing/train_data/1/656.bmp
#   inflating: real_or_drawing/train_data/1/657.bmp
#   inflating: real_or_drawing/train_data/1/658.bmp
#   inflating: real_or_drawing/train_data/1/659.bmp
#   inflating: real_or_drawing/train_data/1/660.bmp
#   inflating: real_or_drawing/train_data/1/661.bmp
#   inflating: real_or_drawing/train_data/1/662.bmp
#   inflating: real_or_drawing/train_data/1/663.bmp
#   inflating: real_or_drawing/train_data/1/664.bmp
#   inflating: real_or_drawing/train_data/1/665.bmp
#   inflating: real_or_drawing/train_data/1/666.bmp
#   inflating: real_or_drawing/train_data/1/667.bmp
#   inflating: real_or_drawing/train_data/1/668.bmp
#   inflating: real_or_drawing/train_data/1/669.bmp
#   inflating: real_or_drawing/train_data/1/670.bmp
#   inflating: real_or_drawing/train_data/1/671.bmp
#   inflating: real_or_drawing/train_data/1/672.bmp
#   inflating: real_or_drawing/train_data/1/673.bmp
#   inflating: real_or_drawing/train_data/1/674.bmp
#   inflating: real_or_drawing/train_data/1/675.bmp
#   inflating: real_or_drawing/train_data/1/676.bmp
#   inflating: real_or_drawing/train_data/1/677.bmp
#   inflating: real_or_drawing/train_data/1/678.bmp
#   inflating: real_or_drawing/train_data/1/679.bmp
#   inflating: real_or_drawing/train_data/1/680.bmp
#   inflating: real_or_drawing/train_data/1/681.bmp
#   inflating: real_or_drawing/train_data/1/682.bmp
#   inflating: real_or_drawing/train_data/1/683.bmp
#   inflating: real_or_drawing/train_data/1/684.bmp
#   inflating: real_or_drawing/train_data/1/685.bmp
#   inflating: real_or_drawing/train_data/1/686.bmp
#   inflating: real_or_drawing/train_data/1/687.bmp
#   inflating: real_or_drawing/train_data/1/688.bmp
#   inflating: real_or_drawing/train_data/1/689.bmp
#   inflating: real_or_drawing/train_data/1/690.bmp
#   inflating: real_or_drawing/train_data/1/691.bmp
#   inflating: real_or_drawing/train_data/1/692.bmp
#   inflating: real_or_drawing/train_data/1/693.bmp
#   inflating: real_or_drawing/train_data/1/694.bmp
#   inflating: real_or_drawing/train_data/1/695.bmp
#   inflating: real_or_drawing/train_data/1/696.bmp
#   inflating: real_or_drawing/train_data/1/697.bmp
#   inflating: real_or_drawing/train_data/1/698.bmp
#   inflating: real_or_drawing/train_data/1/699.bmp
#   inflating: real_or_drawing/train_data/1/700.bmp
#   inflating: real_or_drawing/train_data/1/701.bmp
#   inflating: real_or_drawing/train_data/1/702.bmp
#   inflating: real_or_drawing/train_data/1/703.bmp
#   inflating: real_or_drawing/train_data/1/704.bmp
#   inflating: real_or_drawing/train_data/1/705.bmp
#   inflating: real_or_drawing/train_data/1/706.bmp
#   inflating: real_or_drawing/train_data/1/707.bmp
#   inflating: real_or_drawing/train_data/1/708.bmp
#   inflating: real_or_drawing/train_data/1/709.bmp
#   inflating: real_or_drawing/train_data/1/710.bmp
#   inflating: real_or_drawing/train_data/1/711.bmp
#   inflating: real_or_drawing/train_data/1/712.bmp
#   inflating: real_or_drawing/train_data/1/713.bmp
#   inflating: real_or_drawing/train_data/1/714.bmp
#   inflating: real_or_drawing/train_data/1/715.bmp
#   inflating: real_or_drawing/train_data/1/716.bmp
#   inflating: real_or_drawing/train_data/1/717.bmp
#   inflating: real_or_drawing/train_data/1/718.bmp
#   inflating: real_or_drawing/train_data/1/719.bmp
#   inflating: real_or_drawing/train_data/1/720.bmp
#   inflating: real_or_drawing/train_data/1/721.bmp
#   inflating: real_or_drawing/train_data/1/722.bmp
#   inflating: real_or_drawing/train_data/1/723.bmp
#   inflating: real_or_drawing/train_data/1/724.bmp
#   inflating: real_or_drawing/train_data/1/725.bmp
#   inflating: real_or_drawing/train_data/1/726.bmp
#   inflating: real_or_drawing/train_data/1/727.bmp
#   inflating: real_or_drawing/train_data/1/728.bmp
#   inflating: real_or_drawing/train_data/1/729.bmp
#   inflating: real_or_drawing/train_data/1/730.bmp
#   inflating: real_or_drawing/train_data/1/731.bmp
#   inflating: real_or_drawing/train_data/1/732.bmp
#   inflating: real_or_drawing/train_data/1/733.bmp
#   inflating: real_or_drawing/train_data/1/734.bmp
#   inflating: real_or_drawing/train_data/1/735.bmp
#   inflating: real_or_drawing/train_data/1/736.bmp
#   inflating: real_or_drawing/train_data/1/737.bmp
#   inflating: real_or_drawing/train_data/1/738.bmp
#   inflating: real_or_drawing/train_data/1/739.bmp
#   inflating: real_or_drawing/train_data/1/740.bmp
#   inflating: real_or_drawing/train_data/1/741.bmp
#   inflating: real_or_drawing/train_data/1/742.bmp
#   inflating: real_or_drawing/train_data/1/743.bmp
#   inflating: real_or_drawing/train_data/1/744.bmp
#   inflating: real_or_drawing/train_data/1/745.bmp
#   inflating: real_or_drawing/train_data/1/746.bmp
#   inflating: real_or_drawing/train_data/1/747.bmp
#   inflating: real_or_drawing/train_data/1/748.bmp
#   inflating: real_or_drawing/train_data/1/749.bmp
#   inflating: real_or_drawing/train_data/1/750.bmp
#   inflating: real_or_drawing/train_data/1/751.bmp
#   inflating: real_or_drawing/train_data/1/752.bmp
#   inflating: real_or_drawing/train_data/1/753.bmp
#   inflating: real_or_drawing/train_data/1/754.bmp
#   inflating: real_or_drawing/train_data/1/755.bmp
#   inflating: real_or_drawing/train_data/1/756.bmp
#   inflating: real_or_drawing/train_data/1/757.bmp
#   inflating: real_or_drawing/train_data/1/758.bmp
#   inflating: real_or_drawing/train_data/1/759.bmp
#   inflating: real_or_drawing/train_data/1/760.bmp
#   inflating: real_or_drawing/train_data/1/761.bmp
#   inflating: real_or_drawing/train_data/1/762.bmp
#   inflating: real_or_drawing/train_data/1/763.bmp
#   inflating: real_or_drawing/train_data/1/764.bmp
#   inflating: real_or_drawing/train_data/1/765.bmp
#   inflating: real_or_drawing/train_data/1/766.bmp
#   inflating: real_or_drawing/train_data/1/767.bmp
#   inflating: real_or_drawing/train_data/1/768.bmp
#   inflating: real_or_drawing/train_data/1/769.bmp
#   inflating: real_or_drawing/train_data/1/770.bmp
#   inflating: real_or_drawing/train_data/1/771.bmp
#   inflating: real_or_drawing/train_data/1/772.bmp
#   inflating: real_or_drawing/train_data/1/773.bmp
#   inflating: real_or_drawing/train_data/1/774.bmp
#   inflating: real_or_drawing/train_data/1/775.bmp
#   inflating: real_or_drawing/train_data/1/776.bmp
#   inflating: real_or_drawing/train_data/1/777.bmp
#   inflating: real_or_drawing/train_data/1/778.bmp
#   inflating: real_or_drawing/train_data/1/779.bmp
#   inflating: real_or_drawing/train_data/1/780.bmp
#   inflating: real_or_drawing/train_data/1/781.bmp
#   inflating: real_or_drawing/train_data/1/782.bmp
#   inflating: real_or_drawing/train_data/1/783.bmp
#   inflating: real_or_drawing/train_data/1/784.bmp
#   inflating: real_or_drawing/train_data/1/785.bmp
#   inflating: real_or_drawing/train_data/1/786.bmp
#   inflating: real_or_drawing/train_data/1/787.bmp
#   inflating: real_or_drawing/train_data/1/788.bmp
#   inflating: real_or_drawing/train_data/1/789.bmp
#   inflating: real_or_drawing/train_data/1/790.bmp
#   inflating: real_or_drawing/train_data/1/791.bmp
#   inflating: real_or_drawing/train_data/1/792.bmp
#   inflating: real_or_drawing/train_data/1/793.bmp
#   inflating: real_or_drawing/train_data/1/794.bmp
#   inflating: real_or_drawing/train_data/1/795.bmp
#   inflating: real_or_drawing/train_data/1/796.bmp
#   inflating: real_or_drawing/train_data/1/797.bmp
#   inflating: real_or_drawing/train_data/1/798.bmp
#   inflating: real_or_drawing/train_data/1/799.bmp
#   inflating: real_or_drawing/train_data/1/800.bmp
#   inflating: real_or_drawing/train_data/1/801.bmp
#   inflating: real_or_drawing/train_data/1/802.bmp
#   inflating: real_or_drawing/train_data/1/803.bmp
#   inflating: real_or_drawing/train_data/1/804.bmp
#   inflating: real_or_drawing/train_data/1/805.bmp
#   inflating: real_or_drawing/train_data/1/806.bmp
#   inflating: real_or_drawing/train_data/1/807.bmp
#   inflating: real_or_drawing/train_data/1/808.bmp
#   inflating: real_or_drawing/train_data/1/809.bmp
#   inflating: real_or_drawing/train_data/1/810.bmp
#   inflating: real_or_drawing/train_data/1/811.bmp
#   inflating: real_or_drawing/train_data/1/812.bmp
#   inflating: real_or_drawing/train_data/1/813.bmp
#   inflating: real_or_drawing/train_data/1/814.bmp
#   inflating: real_or_drawing/train_data/1/815.bmp
#   inflating: real_or_drawing/train_data/1/816.bmp
#   inflating: real_or_drawing/train_data/1/817.bmp
#   inflating: real_or_drawing/train_data/1/818.bmp
#   inflating: real_or_drawing/train_data/1/819.bmp
#   inflating: real_or_drawing/train_data/1/820.bmp
#   inflating: real_or_drawing/train_data/1/821.bmp
#   inflating: real_or_drawing/train_data/1/822.bmp
#   inflating: real_or_drawing/train_data/1/823.bmp
#   inflating: real_or_drawing/train_data/1/824.bmp
#   inflating: real_or_drawing/train_data/1/825.bmp
#   inflating: real_or_drawing/train_data/1/826.bmp
#   inflating: real_or_drawing/train_data/1/827.bmp
#   inflating: real_or_drawing/train_data/1/828.bmp
#   inflating: real_or_drawing/train_data/1/829.bmp
#   inflating: real_or_drawing/train_data/1/830.bmp
#   inflating: real_or_drawing/train_data/1/831.bmp
#   inflating: real_or_drawing/train_data/1/832.bmp
#   inflating: real_or_drawing/train_data/1/833.bmp
#   inflating: real_or_drawing/train_data/1/834.bmp
#   inflating: real_or_drawing/train_data/1/835.bmp
#   inflating: real_or_drawing/train_data/1/836.bmp
#   inflating: real_or_drawing/train_data/1/837.bmp
#   inflating: real_or_drawing/train_data/1/838.bmp
#   inflating: real_or_drawing/train_data/1/839.bmp
#   inflating: real_or_drawing/train_data/1/840.bmp
#   inflating: real_or_drawing/train_data/1/841.bmp
#   inflating: real_or_drawing/train_data/1/842.bmp
#   inflating: real_or_drawing/train_data/1/843.bmp
#   inflating: real_or_drawing/train_data/1/844.bmp
#   inflating: real_or_drawing/train_data/1/845.bmp
#   inflating: real_or_drawing/train_data/1/846.bmp
#   inflating: real_or_drawing/train_data/1/847.bmp
#   inflating: real_or_drawing/train_data/1/848.bmp
#   inflating: real_or_drawing/train_data/1/849.bmp
#   inflating: real_or_drawing/train_data/1/850.bmp
#   inflating: real_or_drawing/train_data/1/851.bmp
#   inflating: real_or_drawing/train_data/1/852.bmp
#   inflating: real_or_drawing/train_data/1/853.bmp
#   inflating: real_or_drawing/train_data/1/854.bmp
#   inflating: real_or_drawing/train_data/1/855.bmp
#   inflating: real_or_drawing/train_data/1/856.bmp
#   inflating: real_or_drawing/train_data/1/857.bmp
#   inflating: real_or_drawing/train_data/1/858.bmp
#   inflating: real_or_drawing/train_data/1/859.bmp
#   inflating: real_or_drawing/train_data/1/860.bmp
#   inflating: real_or_drawing/train_data/1/861.bmp
#   inflating: real_or_drawing/train_data/1/862.bmp
#   inflating: real_or_drawing/train_data/1/863.bmp
#   inflating: real_or_drawing/train_data/1/864.bmp
#   inflating: real_or_drawing/train_data/1/865.bmp
#   inflating: real_or_drawing/train_data/1/866.bmp
#   inflating: real_or_drawing/train_data/1/867.bmp
#   inflating: real_or_drawing/train_data/1/868.bmp
#   inflating: real_or_drawing/train_data/1/869.bmp
#   inflating: real_or_drawing/train_data/1/870.bmp
#   inflating: real_or_drawing/train_data/1/871.bmp
#   inflating: real_or_drawing/train_data/1/872.bmp
#   inflating: real_or_drawing/train_data/1/873.bmp
#   inflating: real_or_drawing/train_data/1/874.bmp
#   inflating: real_or_drawing/train_data/1/875.bmp
#   inflating: real_or_drawing/train_data/1/876.bmp
#   inflating: real_or_drawing/train_data/1/877.bmp
#   inflating: real_or_drawing/train_data/1/878.bmp
#   inflating: real_or_drawing/train_data/1/879.bmp
#   inflating: real_or_drawing/train_data/1/880.bmp
#   inflating: real_or_drawing/train_data/1/881.bmp
#   inflating: real_or_drawing/train_data/1/882.bmp
#   inflating: real_or_drawing/train_data/1/883.bmp
#   inflating: real_or_drawing/train_data/1/884.bmp
#   inflating: real_or_drawing/train_data/1/885.bmp
#   inflating: real_or_drawing/train_data/1/886.bmp
#   inflating: real_or_drawing/train_data/1/887.bmp
#   inflating: real_or_drawing/train_data/1/888.bmp
#   inflating: real_or_drawing/train_data/1/889.bmp
#   inflating: real_or_drawing/train_data/1/890.bmp
#   inflating: real_or_drawing/train_data/1/891.bmp
#   inflating: real_or_drawing/train_data/1/892.bmp
#   inflating: real_or_drawing/train_data/1/893.bmp
#   inflating: real_or_drawing/train_data/1/894.bmp
#   inflating: real_or_drawing/train_data/1/895.bmp
#   inflating: real_or_drawing/train_data/1/896.bmp
#   inflating: real_or_drawing/train_data/1/897.bmp
#   inflating: real_or_drawing/train_data/1/898.bmp
#   inflating: real_or_drawing/train_data/1/899.bmp
#   inflating: real_or_drawing/train_data/1/900.bmp
#   inflating: real_or_drawing/train_data/1/901.bmp
#   inflating: real_or_drawing/train_data/1/902.bmp
#   inflating: real_or_drawing/train_data/1/903.bmp
#   inflating: real_or_drawing/train_data/1/904.bmp
#   inflating: real_or_drawing/train_data/1/905.bmp
#   inflating: real_or_drawing/train_data/1/906.bmp
#   inflating: real_or_drawing/train_data/1/907.bmp
#   inflating: real_or_drawing/train_data/1/908.bmp
#   inflating: real_or_drawing/train_data/1/909.bmp
#   inflating: real_or_drawing/train_data/1/910.bmp
#   inflating: real_or_drawing/train_data/1/911.bmp
#   inflating: real_or_drawing/train_data/1/912.bmp
#   inflating: real_or_drawing/train_data/1/913.bmp
#   inflating: real_or_drawing/train_data/1/914.bmp
#   inflating: real_or_drawing/train_data/1/915.bmp
#   inflating: real_or_drawing/train_data/1/916.bmp
#   inflating: real_or_drawing/train_data/1/917.bmp
#   inflating: real_or_drawing/train_data/1/918.bmp
#   inflating: real_or_drawing/train_data/1/919.bmp
#   inflating: real_or_drawing/train_data/1/920.bmp
#   inflating: real_or_drawing/train_data/1/921.bmp
#   inflating: real_or_drawing/train_data/1/922.bmp
#   inflating: real_or_drawing/train_data/1/923.bmp
#   inflating: real_or_drawing/train_data/1/924.bmp
#   inflating: real_or_drawing/train_data/1/925.bmp
#   inflating: real_or_drawing/train_data/1/926.bmp
#   inflating: real_or_drawing/train_data/1/927.bmp
#   inflating: real_or_drawing/train_data/1/928.bmp
#   inflating: real_or_drawing/train_data/1/929.bmp
#   inflating: real_or_drawing/train_data/1/930.bmp
#   inflating: real_or_drawing/train_data/1/931.bmp
# ...
#   inflating: real_or_drawing/train_data/9/4699.bmp
#   inflating: real_or_drawing/train_data/9/4700.bmp
#   inflating: real_or_drawing/train_data/9/4701.bmp
#   inflating: real_or_drawing/train_data/9/4702.bmp
#   inflating: real_or_drawing/train_data/9/4703.bmp
#   inflating: real_or_drawing/train_data/9/4704.bmp
#   inflating: real_or_drawing/train_data/9/4705.bmp
#   inflating: real_or_drawing/train_data/9/4706.bmp
#   inflating: real_or_drawing/train_data/9/4707.bmp
#   inflating: real_or_drawing/train_data/9/4708.bmp
#   inflating: real_or_drawing/train_data/9/4709.bmp
#   inflating: real_or_drawing/train_data/9/4710.bmp
#   inflating: real_or_drawing/train_data/9/4711.bmp
#   inflating: real_or_drawing/train_data/9/4712.bmp
#   inflating: real_or_drawing/train_data/9/4713.bmp
#   inflating: real_or_drawing/train_data/9/4714.bmp
#   inflating: real_or_drawing/train_data/9/4715.bmp
#   inflating: real_or_drawing/train_data/9/4716.bmp
#   inflating: real_or_drawing/train_data/9/4717.bmp
#   inflating: real_or_drawing/train_data/9/4718.bmp
#   inflating: real_or_drawing/train_data/9/4719.bmp
#   inflating: real_or_drawing/train_data/9/4720.bmp
#   inflating: real_or_drawing/train_data/9/4721.bmp
#   inflating: real_or_drawing/train_data/9/4722.bmp
#   inflating: real_or_drawing/train_data/9/4723.bmp
#   inflating: real_or_drawing/train_data/9/4724.bmp
#   inflating: real_or_drawing/train_data/9/4725.bmp
#   inflating: real_or_drawing/train_data/9/4726.bmp
#   inflating: real_or_drawing/train_data/9/4727.bmp
#   inflating: real_or_drawing/train_data/9/4728.bmp
#   inflating: real_or_drawing/train_data/9/4729.bmp
#   inflating: real_or_drawing/train_data/9/4730.bmp
#   inflating: real_or_drawing/train_data/9/4731.bmp
#   inflating: real_or_drawing/train_data/9/4732.bmp
#   inflating: real_or_drawing/train_data/9/4733.bmp
#   inflating: real_or_drawing/train_data/9/4734.bmp
#   inflating: real_or_drawing/train_data/9/4735.bmp
#   inflating: real_or_drawing/train_data/9/4736.bmp
#   inflating: real_or_drawing/train_data/9/4737.bmp
#   inflating: real_or_drawing/train_data/9/4738.bmp
#   inflating: real_or_drawing/train_data/9/4739.bmp
#   inflating: real_or_drawing/train_data/9/4740.bmp
#   inflating: real_or_drawing/train_data/9/4741.bmp
#   inflating: real_or_drawing/train_data/9/4742.bmp
#   inflating: real_or_drawing/train_data/9/4743.bmp
#   inflating: real_or_drawing/train_data/9/4744.bmp
#   inflating: real_or_drawing/train_data/9/4745.bmp
#   inflating: real_or_drawing/train_data/9/4746.bmp
#   inflating: real_or_drawing/train_data/9/4747.bmp
#   inflating: real_or_drawing/train_data/9/4748.bmp
#   inflating: real_or_drawing/train_data/9/4749.bmp
#   inflating: real_or_drawing/train_data/9/4750.bmp
#   inflating: real_or_drawing/train_data/9/4751.bmp
#   inflating: real_or_drawing/train_data/9/4752.bmp
#   inflating: real_or_drawing/train_data/9/4753.bmp
#   inflating: real_or_drawing/train_data/9/4754.bmp
#   inflating: real_or_drawing/train_data/9/4755.bmp
#   inflating: real_or_drawing/train_data/9/4756.bmp
#   inflating: real_or_drawing/train_data/9/4757.bmp
#   inflating: real_or_drawing/train_data/9/4758.bmp
#   inflating: real_or_drawing/train_data/9/4759.bmp
#   inflating: real_or_drawing/train_data/9/4760.bmp
#   inflating: real_or_drawing/train_data/9/4761.bmp
#   inflating: real_or_drawing/train_data/9/4762.bmp
#   inflating: real_or_drawing/train_data/9/4763.bmp
#   inflating: real_or_drawing/train_data/9/4764.bmp
#   inflating: real_or_drawing/train_data/9/4765.bmp
#   inflating: real_or_drawing/train_data/9/4766.bmp
#   inflating: real_or_drawing/train_data/9/4767.bmp
#   inflating: real_or_drawing/train_data/9/4768.bmp
#   inflating: real_or_drawing/train_data/9/4769.bmp
#   inflating: real_or_drawing/train_data/9/4770.bmp
#   inflating: real_or_drawing/train_data/9/4771.bmp
#   inflating: real_or_drawing/train_data/9/4772.bmp
#   inflating: real_or_drawing/train_data/9/4773.bmp
#   inflating: real_or_drawing/train_data/9/4774.bmp
#   inflating: real_or_drawing/train_data/9/4775.bmp
#   inflating: real_or_drawing/train_data/9/4776.bmp
#   inflating: real_or_drawing/train_data/9/4777.bmp
#   inflating: real_or_drawing/train_data/9/4778.bmp
#   inflating: real_or_drawing/train_data/9/4779.bmp
#   inflating: real_or_drawing/train_data/9/4780.bmp
#   inflating: real_or_drawing/train_data/9/4781.bmp
#   inflating: real_or_drawing/train_data/9/4782.bmp
#   inflating: real_or_drawing/train_data/9/4783.bmp
#   inflating: real_or_drawing/train_data/9/4784.bmp
#   inflating: real_or_drawing/train_data/9/4785.bmp
#   inflating: real_or_drawing/train_data/9/4786.bmp
#   inflating: real_or_drawing/train_data/9/4787.bmp
#   inflating: real_or_drawing/train_data/9/4788.bmp
#   inflating: real_or_drawing/train_data/9/4789.bmp
#   inflating: real_or_drawing/train_data/9/4790.bmp
#   inflating: real_or_drawing/train_data/9/4791.bmp
#   inflating: real_or_drawing/train_data/9/4792.bmp
#   inflating: real_or_drawing/train_data/9/4793.bmp
#   inflating: real_or_drawing/train_data/9/4794.bmp
#   inflating: real_or_drawing/train_data/9/4795.bmp
#   inflating: real_or_drawing/train_data/9/4796.bmp
#   inflating: real_or_drawing/train_data/9/4797.bmp
#   inflating: real_or_drawing/train_data/9/4798.bmp
#   inflating: real_or_drawing/train_data/9/4799.bmp
#   inflating: real_or_drawing/train_data/9/4800.bmp
#   inflating: real_or_drawing/train_data/9/4801.bmp
#   inflating: real_or_drawing/train_data/9/4802.bmp
#   inflating: real_or_drawing/train_data/9/4803.bmp
#   inflating: real_or_drawing/train_data/9/4804.bmp
#   inflating: real_or_drawing/train_data/9/4805.bmp
#   inflating: real_or_drawing/train_data/9/4806.bmp
#   inflating: real_or_drawing/train_data/9/4807.bmp
#   inflating: real_or_drawing/train_data/9/4808.bmp
#   inflating: real_or_drawing/train_data/9/4809.bmp
#   inflating: real_or_drawing/train_data/9/4810.bmp
#   inflating: real_or_drawing/train_data/9/4811.bmp
#   inflating: real_or_drawing/train_data/9/4812.bmp
#   inflating: real_or_drawing/train_data/9/4813.bmp
#   inflating: real_or_drawing/train_data/9/4814.bmp
#   inflating: real_or_drawing/train_data/9/4815.bmp
#   inflating: real_or_drawing/train_data/9/4816.bmp
#   inflating: real_or_drawing/train_data/9/4817.bmp
#   inflating: real_or_drawing/train_data/9/4818.bmp
#   inflating: real_or_drawing/train_data/9/4819.bmp
#   inflating: real_or_drawing/train_data/9/4820.bmp
#   inflating: real_or_drawing/train_data/9/4821.bmp
#   inflating: real_or_drawing/train_data/9/4822.bmp
#   inflating: real_or_drawing/train_data/9/4823.bmp
#   inflating: real_or_drawing/train_data/9/4824.bmp
#   inflating: real_or_drawing/train_data/9/4825.bmp
#   inflating: real_or_drawing/train_data/9/4826.bmp
#   inflating: real_or_drawing/train_data/9/4827.bmp
#   inflating: real_or_drawing/train_data/9/4828.bmp
#   inflating: real_or_drawing/train_data/9/4829.bmp
#   inflating: real_or_drawing/train_data/9/4830.bmp
#   inflating: real_or_drawing/train_data/9/4831.bmp
#   inflating: real_or_drawing/train_data/9/4832.bmp
#   inflating: real_or_drawing/train_data/9/4833.bmp
#   inflating: real_or_drawing/train_data/9/4834.bmp
#   inflating: real_or_drawing/train_data/9/4835.bmp
#   inflating: real_or_drawing/train_data/9/4836.bmp
#   inflating: real_or_drawing/train_data/9/4837.bmp
#   inflating: real_or_drawing/train_data/9/4838.bmp
#   inflating: real_or_drawing/train_data/9/4839.bmp
#   inflating: real_or_drawing/train_data/9/4840.bmp
#   inflating: real_or_drawing/train_data/9/4841.bmp
#   inflating: real_or_drawing/train_data/9/4842.bmp
#   inflating: real_or_drawing/train_data/9/4843.bmp
#   inflating: real_or_drawing/train_data/9/4844.bmp
#   inflating: real_or_drawing/train_data/9/4845.bmp
#   inflating: real_or_drawing/train_data/9/4846.bmp
#   inflating: real_or_drawing/train_data/9/4847.bmp
#   inflating: real_or_drawing/train_data/9/4848.bmp
#   inflating: real_or_drawing/train_data/9/4849.bmp
#   inflating: real_or_drawing/train_data/9/4850.bmp
#   inflating: real_or_drawing/train_data/9/4851.bmp
#   inflating: real_or_drawing/train_data/9/4852.bmp
#   inflating: real_or_drawing/train_data/9/4853.bmp
#   inflating: real_or_drawing/train_data/9/4854.bmp
#   inflating: real_or_drawing/train_data/9/4855.bmp
#   inflating: real_or_drawing/train_data/9/4856.bmp
#   inflating: real_or_drawing/train_data/9/4857.bmp
#   inflating: real_or_drawing/train_data/9/4858.bmp
#   inflating: real_or_drawing/train_data/9/4859.bmp
#   inflating: real_or_drawing/train_data/9/4860.bmp
#   inflating: real_or_drawing/train_data/9/4861.bmp
#   inflating: real_or_drawing/train_data/9/4862.bmp
#   inflating: real_or_drawing/train_data/9/4863.bmp
#   inflating: real_or_drawing/train_data/9/4864.bmp
#   inflating: real_or_drawing/train_data/9/4865.bmp
#   inflating: real_or_drawing/train_data/9/4866.bmp
#   inflating: real_or_drawing/train_data/9/4867.bmp
#   inflating: real_or_drawing/train_data/9/4868.bmp
#   inflating: real_or_drawing/train_data/9/4869.bmp
#   inflating: real_or_drawing/train_data/9/4870.bmp
#   inflating: real_or_drawing/train_data/9/4871.bmp
#   inflating: real_or_drawing/train_data/9/4872.bmp
#   inflating: real_or_drawing/train_data/9/4873.bmp
#   inflating: real_or_drawing/train_data/9/4874.bmp
#   inflating: real_or_drawing/train_data/9/4875.bmp
#   inflating: real_or_drawing/train_data/9/4876.bmp
#   inflating: real_or_drawing/train_data/9/4877.bmp
#   inflating: real_or_drawing/train_data/9/4878.bmp
#   inflating: real_or_drawing/train_data/9/4879.bmp
#   inflating: real_or_drawing/train_data/9/4880.bmp
#   inflating: real_or_drawing/train_data/9/4881.bmp
#   inflating: real_or_drawing/train_data/9/4882.bmp
#   inflating: real_or_drawing/train_data/9/4883.bmp
#   inflating: real_or_drawing/train_data/9/4884.bmp
#   inflating: real_or_drawing/train_data/9/4885.bmp
#   inflating: real_or_drawing/train_data/9/4886.bmp
#   inflating: real_or_drawing/train_data/9/4887.bmp
#   inflating: real_or_drawing/train_data/9/4888.bmp
#   inflating: real_or_drawing/train_data/9/4889.bmp
#   inflating: real_or_drawing/train_data/9/4890.bmp
#   inflating: real_or_drawing/train_data/9/4891.bmp
#   inflating: real_or_drawing/train_data/9/4892.bmp
#   inflating: real_or_drawing/train_data/9/4893.bmp
#   inflating: real_or_drawing/train_data/9/4894.bmp
#   inflating: real_or_drawing/train_data/9/4895.bmp
#   inflating: real_or_drawing/train_data/9/4896.bmp
#   inflating: real_or_drawing/train_data/9/4897.bmp
#   inflating: real_or_drawing/train_data/9/4898.bmp
#   inflating: real_or_drawing/train_data/9/4899.bmp
#   inflating: real_or_drawing/train_data/9/4900.bmp
#   inflating: real_or_drawing/train_data/9/4901.bmp
#   inflating: real_or_drawing/train_data/9/4902.bmp
#   inflating: real_or_drawing/train_data/9/4903.bmp
#   inflating: real_or_drawing/train_data/9/4904.bmp
#   inflating: real_or_drawing/train_data/9/4905.bmp
#   inflating: real_or_drawing/train_data/9/4906.bmp
#   inflating: real_or_drawing/train_data/9/4907.bmp
#   inflating: real_or_drawing/train_data/9/4908.bmp
#   inflating: real_or_drawing/train_data/9/4909.bmp
#   inflating: real_or_drawing/train_data/9/4910.bmp
#   inflating: real_or_drawing/train_data/9/4911.bmp
#   inflating: real_or_drawing/train_data/9/4912.bmp
#   inflating: real_or_drawing/train_data/9/4913.bmp
#   inflating: real_or_drawing/train_data/9/4914.bmp
#   inflating: real_or_drawing/train_data/9/4915.bmp
#   inflating: real_or_drawing/train_data/9/4916.bmp
#   inflating: real_or_drawing/train_data/9/4917.bmp
#   inflating: real_or_drawing/train_data/9/4918.bmp
#   inflating: real_or_drawing/train_data/9/4919.bmp
#   inflating: real_or_drawing/train_data/9/4920.bmp
#   inflating: real_or_drawing/train_data/9/4921.bmp
#   inflating: real_or_drawing/train_data/9/4922.bmp
#   inflating: real_or_drawing/train_data/9/4923.bmp
#   inflating: real_or_drawing/train_data/9/4924.bmp
#   inflating: real_or_drawing/train_data/9/4925.bmp
#   inflating: real_or_drawing/train_data/9/4926.bmp
#   inflating: real_or_drawing/train_data/9/4927.bmp
#   inflating: real_or_drawing/train_data/9/4928.bmp
#   inflating: real_or_drawing/train_data/9/4929.bmp
#   inflating: real_or_drawing/train_data/9/4930.bmp
#   inflating: real_or_drawing/train_data/9/4931.bmp
#   inflating: real_or_drawing/train_data/9/4932.bmp
#   inflating: real_or_drawing/train_data/9/4933.bmp
#   inflating: real_or_drawing/train_data/9/4934.bmp
#   inflating: real_or_drawing/train_data/9/4935.bmp
#   inflating: real_or_drawing/train_data/9/4936.bmp
#   inflating: real_or_drawing/train_data/9/4937.bmp
#   inflating: real_or_drawing/train_data/9/4938.bmp
#   inflating: real_or_drawing/train_data/9/4939.bmp
#   inflating: real_or_drawing/train_data/9/4940.bmp
#   inflating: real_or_drawing/train_data/9/4941.bmp
#   inflating: real_or_drawing/train_data/9/4942.bmp
#   inflating: real_or_drawing/train_data/9/4943.bmp
#   inflating: real_or_drawing/train_data/9/4944.bmp
#   inflating: real_or_drawing/train_data/9/4945.bmp
#   inflating: real_or_drawing/train_data/9/4946.bmp
#   inflating: real_or_drawing/train_data/9/4947.bmp
#   inflating: real_or_drawing/train_data/9/4948.bmp
#   inflating: real_or_drawing/train_data/9/4949.bmp
#   inflating: real_or_drawing/train_data/9/4950.bmp
#   inflating: real_or_drawing/train_data/9/4951.bmp
#   inflating: real_or_drawing/train_data/9/4952.bmp
#   inflating: real_or_drawing/train_data/9/4953.bmp
#   inflating: real_or_drawing/train_data/9/4954.bmp
#   inflating: real_or_drawing/train_data/9/4955.bmp
#   inflating: real_or_drawing/train_data/9/4956.bmp
#   inflating: real_or_drawing/train_data/9/4957.bmp
#   inflating: real_or_drawing/train_data/9/4958.bmp
#   inflating: real_or_drawing/train_data/9/4959.bmp
#   inflating: real_or_drawing/train_data/9/4960.bmp
#   inflating: real_or_drawing/train_data/9/4961.bmp
#   inflating: real_or_drawing/train_data/9/4962.bmp
#   inflating: real_or_drawing/train_data/9/4963.bmp
#   inflating: real_or_drawing/train_data/9/4964.bmp
#   inflating: real_or_drawing/train_data/9/4965.bmp
#   inflating: real_or_drawing/train_data/9/4966.bmp
#   inflating: real_or_drawing/train_data/9/4967.bmp
#   inflating: real_or_drawing/train_data/9/4968.bmp
#   inflating: real_or_drawing/train_data/9/4969.bmp
#   inflating: real_or_drawing/train_data/9/4970.bmp
#   inflating: real_or_drawing/train_data/9/4971.bmp
#   inflating: real_or_drawing/train_data/9/4972.bmp
#   inflating: real_or_drawing/train_data/9/4973.bmp
#   inflating: real_or_drawing/train_data/9/4974.bmp
#   inflating: real_or_drawing/train_data/9/4975.bmp
#   inflating: real_or_drawing/train_data/9/4976.bmp
#   inflating: real_or_drawing/train_data/9/4977.bmp
#   inflating: real_or_drawing/train_data/9/4978.bmp
#   inflating: real_or_drawing/train_data/9/4979.bmp
#   inflating: real_or_drawing/train_data/9/4980.bmp
#   inflating: real_or_drawing/train_data/9/4981.bmp
#   inflating: real_or_drawing/train_data/9/4982.bmp
#   inflating: real_or_drawing/train_data/9/4983.bmp
#   inflating: real_or_drawing/train_data/9/4984.bmp
#   inflating: real_or_drawing/train_data/9/4985.bmp
#   inflating: real_or_drawing/train_data/9/4986.bmp
#   inflating: real_or_drawing/train_data/9/4987.bmp
#   inflating: real_or_drawing/train_data/9/4988.bmp
#   inflating: real_or_drawing/train_data/9/4989.bmp
#   inflating: real_or_drawing/train_data/9/4990.bmp
#   inflating: real_or_drawing/train_data/9/4991.bmp
#   inflating: real_or_drawing/train_data/9/4992.bmp
#   inflating: real_or_drawing/train_data/9/4993.bmp
#   inflating: real_or_drawing/train_data/9/4994.bmp
#   inflating: real_or_drawing/train_data/9/4995.bmp
#   inflating: real_or_drawing/train_data/9/4996.bmp
#   inflating: real_or_drawing/train_data/9/4997.bmp
#   inflating: real_or_drawing/train_data/9/4998.bmp
#   inflating: real_or_drawing/train_data/9/4999.bmp

# %%
import matplotlib.pyplot as plt

def no_axis_show(img, title='', cmap=None):
  # imshow, and set the interpolation mode to be "nearest"。
  fig = plt.imshow(img, interpolation='nearest', cmap=cmap)
  # do not show the axes in the images.
  fig.axes.get_xaxis().set_visible(False)
  fig.axes.get_yaxis().set_visible(False)
  plt.title(title)

titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'real_or_drawing/train_data/{i}/{500*i}.bmp'), title=titles[i])

# %%
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'real_or_drawing/test_data/0/' + str(i).rjust(5, '0') + '.bmp'))

# %% [markdown]
# # Special Domain Knowledge
#
# When we graffiti, we usually draw the outline only, therefore we can perform edge detection processing on the source data to make it more similar to the target data.
#
#
# ## Canny Edge Detection
# The implementation of Canny Edge Detection is as follow.
# The algorithm will not be describe thoroughly here.  If you are interested, please refer to the wiki or [here](https://medium.com/@pomelyu5199/canny-edge-detector-%E5%AF%A6%E4%BD%9C-opencv-f7d1a0a57d19).
#
# We only need two parameters to implement Canny Edge Detection with CV2:  `low_threshold` and `high_threshold`.
#
# ```cv2.Canny(image, low_threshold, high_threshold)```
#
# Simply put, when the edge value exceeds the high_threshold, we determine it as an edge. If the edge value is only above low_threshold, we will then determine whether it is an edge or not.
#
# Let's implement it on the source data.

# %%
import cv2
import matplotlib.pyplot as plt
titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))

original_img = plt.imread(f'real_or_drawing/train_data/0/0.bmp')
plt.subplot(1, 5, 1)
no_axis_show(original_img, title='original')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

canny_50100 = cv2.Canny(gray_img, 50, 100)
plt.subplot(1, 5, 3)
no_axis_show(canny_50100, title='Canny(50, 100)', cmap='gray')

canny_150200 = cv2.Canny(gray_img, 150, 200)
plt.subplot(1, 5, 4)
no_axis_show(canny_150200, title='Canny(150, 200)', cmap='gray')

canny_250300 = cv2.Canny(gray_img, 250, 300)
plt.subplot(1, 5, 5)
no_axis_show(canny_250300, title='Canny(250, 300)', cmap='gray')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   from ipykernel import kernelapp as app

# %% [markdown]
# # Data Process
#
#
# The data is suitible for `torchvision.ImageFolder`. You can create a dataset with `torchvision.ImageFolder`. Details for image augmentation please refer to the comments in the following codes.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Function
 
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
 
source_transform = transforms.Compose([
    # Turn RGB to grayscale. (Bacause Canny do not support RGB images.)
    transforms.Grayscale(),
    # cv2 do not support skimage.Image, so we transform it to np.array, 
    # and then adopt cv2.Canny algorithm.
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), 170, 300)),
    # Transform np.array back to the skimage.Image.
    transforms.ToPILImage(),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
target_transform = transforms.Compose([
    # Turn RGB to grayscale.
    transforms.Grayscale(),
    # Resize: size of source data is 32x32, thus we need to 
    #  enlarge the size of target data from 28x28 to 32x32。
    transforms.Resize((32, 32)),
    # 50% Horizontal Flip. (For Augmentation)
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
 
source_dataset = ImageFolder('real_or_drawing/train_data', transform=source_transform)
target_dataset = ImageFolder('real_or_drawing/test_data', transform=target_transform)
 
source_dataloader = DataLoader(source_dataset, batch_size=32, shuffle=True)
target_dataloader = DataLoader(target_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(target_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# # Model
#
# Feature Extractor: Classic VGG-like architecture
#
# Label Predictor / Domain Classifier: Linear models.

# %%
class FeatureExtractor(nn.Module):

    def __init__(self):
        super(FeatureExtractor, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            # nn.Conv2d(256, 256, 3, 1, 1),
            # nn.BatchNorm2d(256),
            # nn.ReLU(),
            # nn.Conv2d(256, 256, 3, 1, 1),
            # nn.BatchNorm2d(256),
            # nn.ReLU(),
            # nn.Conv2d(256, 256, 3, 1, 1),
            # nn.BatchNorm2d(256),
            # nn.ReLU(),


            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        # self.conv =  nn.Sequential(
        #     nn.Conv2d(1, 3, 3, 1, 1),
        #     nn.BatchNorm2d(3),
        #     nn.ReLU(),
        #     torchvision.models.resnet18(pretrained=False),
        #     nn.Linear(1000, 1000),
        #     nn.ReLU(),
        #     nn.Linear(1000, 512),
        # )
        
    def forward(self, x):
        x = self.conv(x).squeeze()
        return x

class LabelPredictor(nn.Module):

    def __init__(self):
        super(LabelPredictor, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),

            nn.Linear(256, 10),
        )

    def forward(self, h):
        c = self.layer(h)
        return c

class DomainClassifier(nn.Module):

    def __init__(self):
        super(DomainClassifier, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),

            # nn.Linear(512, 512),
            # nn.BatchNorm1d(512),
            # nn.ReLU(),

            # nn.Linear(512, 512),
            # nn.BatchNorm1d(512),
            # nn.ReLU(),

            nn.Linear(256, 1),
        )

    def forward(self, h):
        y = self.layer(h)
        return y

# %% [markdown]
# # Pre-processing
#
# Here we use Adam as our optimizor.

# %%
feature_extractor = FeatureExtractor().cuda()
label_predictor = LabelPredictor().cuda()
domain_classifier = DomainClassifier().cuda()

class_criterion = nn.CrossEntropyLoss()
domain_criterion = nn.BCEWithLogitsLoss()

optimizer_F = optim.Adam(feature_extractor.parameters())
optimizer_C = optim.Adam(label_predictor.parameters())
optimizer_D = optim.Adam(domain_classifier.parameters())

# %% [markdown]
# # Start Training
#
#
# ## DaNN Implementation
#
# In the original paper, Gradient Reversal Layer is used.
# Feature Extractor, Label Predictor, and Domain Classifier are all trained at the same time. In this code, we train Domain Classifier first, and then train our Feature Extractor (same concept as Generator and Discriminator training process in GAN).
#
# ## Reminder
# * Lambda, which controls the domain adversarial loss, is adaptive in the original paper. You can refer to [the original work](https://arxiv.org/pdf/1505.07818.pdf) . Here lambda is set to 0.1.
# * We do not have the label to target data, you can only evaluate your model by uploading your result to kaggle.:)

# %%
def train_epoch(source_dataloader, target_dataloader, lamb):
    '''
      Args:
        source_dataloader: source data的dataloader
        target_dataloader: target data的dataloader
        lamb: control the balance of domain adaptatoin and classification.
    '''

    # D loss: Domain Classifier的loss
    # F loss: Feature Extrator & Label Predictor的loss
    running_D_loss, running_F_loss = 0.0, 0.0
    total_hit, total_num = 0.0, 0.0

    for i, ((source_data, source_label), (target_data, _)) in enumerate(zip(source_dataloader, target_dataloader)):

        source_data = source_data.cuda()
        source_label = source_label.cuda()
        target_data = target_data.cuda()
        
        # Mixed the source data and target data, or it'll mislead the running params
        #   of batch_norm. (runnning mean/var of soucre and target data are different.)
        mixed_data = torch.cat([source_data, target_data], dim=0)
        domain_label = torch.zeros([source_data.shape[0] + target_data.shape[0], 1]).cuda()
        # set domain label of source data to be 1.
        domain_label[:source_data.shape[0]] = 1

        # Step 1 : train domain classifier
        feature = feature_extractor(mixed_data)
        # We don't need to train feature extractor in step 1.
        # Thus we detach the feature neuron to avoid backpropgation.
        domain_logits = domain_classifier(feature.detach())
        loss = domain_criterion(domain_logits, domain_label)
        running_D_loss+= loss.item()
        loss.backward()
        optimizer_D.step()

        # Step 2 : train feature extractor and label classifier
        class_logits = label_predictor(feature[:source_data.shape[0]])
        domain_logits = domain_classifier(feature)
        # loss = cross entropy of classification - lamb * domain binary cross entropy.
        #  The reason why using subtraction is similar to generator loss in disciminator of GAN
        loss = class_criterion(class_logits, source_label) - lamb * domain_criterion(domain_logits, domain_label)
        running_F_loss+= loss.item()
        loss.backward()
        optimizer_F.step()
        optimizer_C.step()

        optimizer_D.zero_grad()
        optimizer_F.zero_grad()
        optimizer_C.zero_grad()

        total_hit += torch.sum(torch.argmax(class_logits, dim=1) == source_label).item()
        total_num += source_data.shape[0]
        print(i, end='\r')

    return running_D_loss / (i+1), running_F_loss / (i+1), total_hit / total_num
total_epoch = 3000
# train 200 epochs
best_loss = 5
for epoch in range(total_epoch):
    lamb = 2 / (1 + np.exp(-10 * epoch / total_epoch)) - 1
    train_D_loss, train_F_loss, train_acc = train_epoch(source_dataloader, target_dataloader, lamb=lamb)

    if (epoch + 1) in [500, 1000, 1500, 2000, 2500, 3000]:
        torch.save(feature_extractor.state_dict(), f'/content/drive/MyDrive/DaNN/extractor_model_{epoch + 1}.bin')


    if best_loss > train_F_loss:
        print('good')
        best_loss = train_F_loss
        torch.save(feature_extractor.state_dict(), f'/content/drive/MyDrive/DaNN/extractor_model.bin')
        torch.save(label_predictor.state_dict(), f'/content/drive/MyDrive/DaNN/predictor_model.bin')

    print('epoch {:>3d}: train D loss: {:6.4f}, train F loss: {:6.4f}, acc {:6.4f}'.format(epoch, train_D_loss, train_F_loss, train_acc))
# Out:
# good
# epoch   0: train D loss: 0.0400, train F loss: 1.7724, acc 0.3736
# good
# epoch   1: train D loss: 0.0180, train F loss: 1.5626, acc 0.4550
# good
# epoch   2: train D loss: 0.0067, train F loss: 1.4416, acc 0.5058
# good
# epoch   3: train D loss: 0.0086, train F loss: 1.3883, acc 0.5168
# good
# epoch   4: train D loss: 0.0109, train F loss: 1.3280, acc 0.5360
# good
# epoch   5: train D loss: 0.0152, train F loss: 1.2843, acc 0.5564
# good
# epoch   6: train D loss: 0.0235, train F loss: 1.2409, acc 0.5744
# good
# epoch   7: train D loss: 0.0199, train F loss: 1.2308, acc 0.5752
# good
# epoch   8: train D loss: 0.0304, train F loss: 1.1659, acc 0.6022
# good
# epoch   9: train D loss: 0.0320, train F loss: 1.1469, acc 0.6078
# good
# epoch  10: train D loss: 0.0965, train F loss: 1.1033, acc 0.6170
# good
# epoch  11: train D loss: 0.1474, train F loss: 1.0782, acc 0.6268
# good
# epoch  12: train D loss: 0.2066, train F loss: 1.0420, acc 0.6436
# good
# epoch  13: train D loss: 0.2135, train F loss: 1.0225, acc 0.6404
# good
# epoch  14: train D loss: 0.2844, train F loss: 0.9717, acc 0.6642
# good
# epoch  15: train D loss: 0.3068, train F loss: 0.9519, acc 0.6710
# good
# epoch  16: train D loss: 0.2702, train F loss: 0.9282, acc 0.6756
# good
# epoch  17: train D loss: 0.3538, train F loss: 0.9110, acc 0.6864
# good
# epoch  18: train D loss: 0.3154, train F loss: 0.8470, acc 0.7094
# good
# epoch  19: train D loss: 0.3291, train F loss: 0.8409, acc 0.7094
# good
# epoch  20: train D loss: 0.3405, train F loss: 0.7987, acc 0.7160
# good
# epoch  21: train D loss: 0.2645, train F loss: 0.7866, acc 0.7246
# good
# epoch  22: train D loss: 0.3707, train F loss: 0.7302, acc 0.7500
# good
# epoch  23: train D loss: 0.4063, train F loss: 0.6881, acc 0.7642
# good
# epoch  24: train D loss: 0.3716, train F loss: 0.6753, acc 0.7616
# good
# epoch  25: train D loss: 0.2006, train F loss: 0.6669, acc 0.7708
# good
# epoch  26: train D loss: 0.3429, train F loss: 0.6409, acc 0.7752
# good
# epoch  27: train D loss: 0.4259, train F loss: 0.6043, acc 0.7844
# good
# epoch  28: train D loss: 0.4019, train F loss: 0.5784, acc 0.7930
# good
# epoch  29: train D loss: 0.4901, train F loss: 0.5602, acc 0.8042
# good
# epoch  30: train D loss: 0.3976, train F loss: 0.5528, acc 0.8084
# good
# epoch  31: train D loss: 0.3624, train F loss: 0.5346, acc 0.8152
# good
# epoch  32: train D loss: 0.3853, train F loss: 0.5062, acc 0.8176
# good
# epoch  33: train D loss: 0.4322, train F loss: 0.4806, acc 0.8314
# epoch  34: train D loss: 0.4156, train F loss: 0.5049, acc 0.8234
# good
# epoch  35: train D loss: 0.4052, train F loss: 0.4180, acc 0.8470
# good
# epoch  36: train D loss: 0.4458, train F loss: 0.4131, acc 0.8494
# epoch  37: train D loss: 0.5068, train F loss: 0.4166, acc 0.8496
# good
# epoch  38: train D loss: 0.4805, train F loss: 0.4041, acc 0.8526
# good
# epoch  39: train D loss: 0.4789, train F loss: 0.3749, acc 0.8604
# good
# epoch  40: train D loss: 0.4573, train F loss: 0.3553, acc 0.8660
# good
# epoch  41: train D loss: 0.4915, train F loss: 0.3515, acc 0.8684
# good
# epoch  42: train D loss: 0.5132, train F loss: 0.3176, acc 0.8828
# good
# epoch  43: train D loss: 0.5128, train F loss: 0.3143, acc 0.8760
# epoch  44: train D loss: 0.4895, train F loss: 0.3196, acc 0.8810
# good
# epoch  45: train D loss: 0.5062, train F loss: 0.2899, acc 0.8924
# good
# epoch  46: train D loss: 0.5004, train F loss: 0.2844, acc 0.8934
# good
# epoch  47: train D loss: 0.4871, train F loss: 0.2739, acc 0.8988
# good
# epoch  48: train D loss: 0.4882, train F loss: 0.2666, acc 0.8908
# good
# epoch  49: train D loss: 0.5042, train F loss: 0.2484, acc 0.9044
# epoch  50: train D loss: 0.4955, train F loss: 0.2643, acc 0.8980
# good
# epoch  51: train D loss: 0.5233, train F loss: 0.2260, acc 0.9096
# epoch  52: train D loss: 0.5331, train F loss: 0.2289, acc 0.9088
# epoch  53: train D loss: 0.5140, train F loss: 0.2363, acc 0.9032
# epoch  54: train D loss: 0.5048, train F loss: 0.2313, acc 0.9038
# good
# epoch  55: train D loss: 0.5051, train F loss: 0.2136, acc 0.9080
# good
# epoch  56: train D loss: 0.5058, train F loss: 0.1971, acc 0.9208
# epoch  57: train D loss: 0.4886, train F loss: 0.2001, acc 0.9192
# good
# epoch  58: train D loss: 0.5470, train F loss: 0.1901, acc 0.9174
# good
# epoch  59: train D loss: 0.5404, train F loss: 0.1829, acc 0.9176
# epoch  60: train D loss: 0.5486, train F loss: 0.1873, acc 0.9206
# good
# epoch  61: train D loss: 0.5187, train F loss: 0.1645, acc 0.9278
# epoch  62: train D loss: 0.5659, train F loss: 0.1846, acc 0.9226
# epoch  63: train D loss: 0.5559, train F loss: 0.1835, acc 0.9212
# good
# epoch  64: train D loss: 0.5763, train F loss: 0.1540, acc 0.9286
# good
# epoch  65: train D loss: 0.5322, train F loss: 0.1440, acc 0.9322
# good
# epoch  66: train D loss: 0.5608, train F loss: 0.1422, acc 0.9328
# epoch  67: train D loss: 0.5155, train F loss: 0.1614, acc 0.9268
# good
# epoch  68: train D loss: 0.5039, train F loss: 0.1299, acc 0.9340
# good
# epoch  69: train D loss: 0.5651, train F loss: 0.1256, acc 0.9362
# good
# epoch  70: train D loss: 0.5198, train F loss: 0.1231, acc 0.9340
# epoch  71: train D loss: 0.5623, train F loss: 0.1410, acc 0.9276
# good
# epoch  72: train D loss: 0.5878, train F loss: 0.1080, acc 0.9420
# epoch  73: train D loss: 0.5465, train F loss: 0.1099, acc 0.9420
# good
# epoch  74: train D loss: 0.5880, train F loss: 0.0961, acc 0.9406
# good
# epoch  75: train D loss: 0.5986, train F loss: 0.0806, acc 0.9470
# epoch  76: train D loss: 0.5831, train F loss: 0.1205, acc 0.9362
# epoch  77: train D loss: 0.5805, train F loss: 0.1165, acc 0.9352
# epoch  78: train D loss: 0.5682, train F loss: 0.0959, acc 0.9436
# epoch  79: train D loss: 0.5527, train F loss: 0.1146, acc 0.9392
# epoch  80: train D loss: 0.5873, train F loss: 0.0837, acc 0.9446
# epoch  81: train D loss: 0.5891, train F loss: 0.0902, acc 0.9446
# good
# epoch  82: train D loss: 0.6303, train F loss: 0.0759, acc 0.9458
# epoch  83: train D loss: 0.6186, train F loss: 0.0961, acc 0.9392
# good
# epoch  84: train D loss: 0.5895, train F loss: 0.0741, acc 0.9466
# epoch  85: train D loss: 0.6296, train F loss: 0.0783, acc 0.9442
# good
# epoch  86: train D loss: 0.5958, train F loss: 0.0470, acc 0.9576
# epoch  87: train D loss: 0.6063, train F loss: 0.0605, acc 0.9508
# good
# epoch  88: train D loss: 0.6152, train F loss: 0.0434, acc 0.9568
# epoch  89: train D loss: 0.6151, train F loss: 0.0583, acc 0.9504
# epoch  90: train D loss: 0.6031, train F loss: 0.0768, acc 0.9428
# epoch  91: train D loss: 0.6267, train F loss: 0.0554, acc 0.9488
# good
# epoch  92: train D loss: 0.6220, train F loss: 0.0369, acc 0.9550
# epoch  93: train D loss: 0.6160, train F loss: 0.0449, acc 0.9508
# epoch  94: train D loss: 0.6369, train F loss: 0.0387, acc 0.9500
# epoch  95: train D loss: 0.6095, train F loss: 0.0372, acc 0.9556
# epoch  96: train D loss: 0.6198, train F loss: 0.0490, acc 0.9522
# epoch  97: train D loss: 0.6134, train F loss: 0.0639, acc 0.9504
# good
# epoch  98: train D loss: 0.6134, train F loss: 0.0305, acc 0.9532
# good
# epoch  99: train D loss: 0.6130, train F loss: 0.0204, acc 0.9622
# epoch 100: train D loss: 0.5957, train F loss: 0.0388, acc 0.9588
# epoch 101: train D loss: 0.6340, train F loss: 0.0388, acc 0.9540
# good
# epoch 102: train D loss: 0.6160, train F loss: 0.0129, acc 0.9624
# epoch 103: train D loss: 0.6289, train F loss: 0.0141, acc 0.9622
# epoch 104: train D loss: 0.6018, train F loss: 0.0378, acc 0.9532
# epoch 105: train D loss: 0.6230, train F loss: 0.0252, acc 0.9540
# epoch 106: train D loss: 0.6210, train F loss: 0.0225, acc 0.9618
# epoch 107: train D loss: 0.6152, train F loss: 0.0218, acc 0.9582
# epoch 108: train D loss: 0.6390, train F loss: 0.0318, acc 0.9518
# good
# epoch 109: train D loss: 0.6250, train F loss: 0.0014, acc 0.9594
# good
# epoch 110: train D loss: 0.6344, train F loss: -0.0039, acc 0.9628
# epoch 111: train D loss: 0.6212, train F loss: -0.0017, acc 0.9614
# good
# epoch 112: train D loss: 0.6367, train F loss: -0.0165, acc 0.9672
# epoch 113: train D loss: 0.6365, train F loss: -0.0061, acc 0.9618
# epoch 114: train D loss: 0.6213, train F loss: -0.0108, acc 0.9628
# epoch 115: train D loss: 0.6226, train F loss: -0.0096, acc 0.9622
# epoch 116: train D loss: 0.6347, train F loss: 0.0024, acc 0.9564
# epoch 117: train D loss: 0.6434, train F loss: 0.0057, acc 0.9578
# good
# epoch 118: train D loss: 0.6435, train F loss: -0.0275, acc 0.9672
# epoch 119: train D loss: 0.6517, train F loss: 0.0023, acc 0.9552
# epoch 120: train D loss: 0.6287, train F loss: -0.0058, acc 0.9594
# epoch 121: train D loss: 0.6125, train F loss: -0.0122, acc 0.9610
# epoch 122: train D loss: 0.6401, train F loss: -0.0216, acc 0.9664
# epoch 123: train D loss: 0.6294, train F loss: -0.0181, acc 0.9674
# epoch 124: train D loss: 0.6338, train F loss: -0.0141, acc 0.9638
# epoch 125: train D loss: 0.6318, train F loss: -0.0147, acc 0.9630
# epoch 126: train D loss: 0.6385, train F loss: -0.0146, acc 0.9600
# good
# epoch 127: train D loss: 0.6422, train F loss: -0.0279, acc 0.9660
# epoch 128: train D loss: 0.6416, train F loss: -0.0164, acc 0.9600
# good
# epoch 129: train D loss: 0.6260, train F loss: -0.0388, acc 0.9664
# epoch 130: train D loss: 0.6424, train F loss: -0.0376, acc 0.9660
# good
# epoch 131: train D loss: 0.6502, train F loss: -0.0451, acc 0.9704
# epoch 132: train D loss: 0.6502, train F loss: -0.0170, acc 0.9622
# good
# epoch 133: train D loss: 0.6462, train F loss: -0.0560, acc 0.9718
# good
# epoch 134: train D loss: 0.6429, train F loss: -0.0631, acc 0.9750
# epoch 135: train D loss: 0.6384, train F loss: -0.0509, acc 0.9678
# epoch 136: train D loss: 0.6481, train F loss: -0.0490, acc 0.9670
# epoch 137: train D loss: 0.6524, train F loss: -0.0326, acc 0.9608
# epoch 138: train D loss: 0.6431, train F loss: -0.0418, acc 0.9664
# epoch 139: train D loss: 0.6440, train F loss: -0.0507, acc 0.9646
# epoch 140: train D loss: 0.6331, train F loss: -0.0608, acc 0.9706
# epoch 141: train D loss: 0.6498, train F loss: -0.0509, acc 0.9668
# epoch 142: train D loss: 0.6335, train F loss: -0.0489, acc 0.9684
# epoch 143: train D loss: 0.6586, train F loss: -0.0287, acc 0.9596
# epoch 144: train D loss: 0.6402, train F loss: -0.0442, acc 0.9650
# good
# epoch 145: train D loss: 0.6401, train F loss: -0.0686, acc 0.9732
# good
# epoch 146: train D loss: 0.6412, train F loss: -0.0739, acc 0.9736
# epoch 147: train D loss: 0.6209, train F loss: -0.0587, acc 0.9712
# epoch 148: train D loss: 0.6684, train F loss: -0.0663, acc 0.9652
# good
# epoch 149: train D loss: 0.6504, train F loss: -0.0766, acc 0.9718
# epoch 150: train D loss: 0.6375, train F loss: -0.0576, acc 0.9698
# good
# epoch 151: train D loss: 0.6507, train F loss: -0.0783, acc 0.9724
# epoch 152: train D loss: 0.6463, train F loss: -0.0672, acc 0.9662
# epoch 153: train D loss: 0.6533, train F loss: -0.0637, acc 0.9670
# good
# epoch 154: train D loss: 0.6402, train F loss: -0.0810, acc 0.9726
# good
# epoch 155: train D loss: 0.6447, train F loss: -0.0893, acc 0.9748
# epoch 156: train D loss: 0.6495, train F loss: -0.0888, acc 0.9732
# epoch 157: train D loss: 0.6347, train F loss: -0.0725, acc 0.9702
# epoch 158: train D loss: 0.6357, train F loss: -0.0884, acc 0.9746
# epoch 159: train D loss: 0.6432, train F loss: -0.0845, acc 0.9716
# epoch 160: train D loss: 0.6587, train F loss: -0.0782, acc 0.9708
# epoch 161: train D loss: 0.6470, train F loss: -0.0760, acc 0.9714
# epoch 162: train D loss: 0.6558, train F loss: -0.0613, acc 0.9644
# epoch 163: train D loss: 0.6454, train F loss: -0.0838, acc 0.9696
# good
# epoch 164: train D loss: 0.6515, train F loss: -0.1019, acc 0.9780
# epoch 165: train D loss: 0.6415, train F loss: -0.0996, acc 0.9742
# epoch 166: train D loss: 0.6436, train F loss: -0.0953, acc 0.9750
# epoch 167: train D loss: 0.6549, train F loss: -0.1016, acc 0.9748
# good
# epoch 168: train D loss: 0.6408, train F loss: -0.1055, acc 0.9774
# epoch 169: train D loss: 0.6504, train F loss: -0.1019, acc 0.9736
# good
# epoch 170: train D loss: 0.6576, train F loss: -0.1096, acc 0.9772
# epoch 171: train D loss: 0.6533, train F loss: -0.0985, acc 0.9738
# epoch 172: train D loss: 0.6620, train F loss: -0.1074, acc 0.9760
# epoch 173: train D loss: 0.6666, train F loss: -0.0917, acc 0.9674
# epoch 174: train D loss: 0.6679, train F loss: -0.1089, acc 0.9708
# epoch 175: train D loss: 0.6389, train F loss: -0.1074, acc 0.9748
# epoch 176: train D loss: 0.6698, train F loss: -0.1030, acc 0.9706
# epoch 177: train D loss: 0.6529, train F loss: -0.1040, acc 0.9720
# good
# epoch 178: train D loss: 0.6497, train F loss: -0.1192, acc 0.9784
# epoch 179: train D loss: 0.6509, train F loss: -0.1106, acc 0.9716
# good
# epoch 180: train D loss: 0.6447, train F loss: -0.1292, acc 0.9792
# epoch 181: train D loss: 0.6671, train F loss: -0.1181, acc 0.9754
# epoch 182: train D loss: 0.6522, train F loss: -0.1057, acc 0.9712
# epoch 183: train D loss: 0.6517, train F loss: -0.1060, acc 0.9688
# epoch 184: train D loss: 0.6627, train F loss: -0.1160, acc 0.9706
# epoch 185: train D loss: 0.6571, train F loss: -0.1256, acc 0.9760
# epoch 186: train D loss: 0.6473, train F loss: -0.1238, acc 0.9776
# epoch 187: train D loss: 0.6585, train F loss: -0.1189, acc 0.9722
# epoch 188: train D loss: 0.6494, train F loss: -0.1117, acc 0.9708
# epoch 189: train D loss: 0.6465, train F loss: -0.1187, acc 0.9728
# epoch 190: train D loss: 0.6402, train F loss: -0.1214, acc 0.9750
# good
# epoch 191: train D loss: 0.6608, train F loss: -0.1298, acc 0.9764
# good
# epoch 192: train D loss: 0.6642, train F loss: -0.1301, acc 0.9730
# good
# epoch 193: train D loss: 0.6541, train F loss: -0.1422, acc 0.9802
# epoch 194: train D loss: 0.6491, train F loss: -0.1286, acc 0.9756
# epoch 195: train D loss: 0.6718, train F loss: -0.1260, acc 0.9724
# epoch 196: train D loss: 0.6497, train F loss: -0.1268, acc 0.9760
# epoch 197: train D loss: 0.6595, train F loss: -0.1378, acc 0.9754
# epoch 198: train D loss: 0.6487, train F loss: -0.1345, acc 0.9760
# epoch 199: train D loss: 0.6542, train F loss: -0.1364, acc 0.9754
# good
# epoch 200: train D loss: 0.6603, train F loss: -0.1453, acc 0.9772
# good
# epoch 201: train D loss: 0.6583, train F loss: -0.1517, acc 0.9810
# epoch 202: train D loss: 0.6452, train F loss: -0.1436, acc 0.9784
# epoch 203: train D loss: 0.6546, train F loss: -0.1457, acc 0.9772
# epoch 204: train D loss: 0.6597, train F loss: -0.1430, acc 0.9768
# good
# epoch 205: train D loss: 0.6731, train F loss: -0.1531, acc 0.9758
# good
# epoch 206: train D loss: 0.6621, train F loss: -0.1586, acc 0.9786
# good
# epoch 207: train D loss: 0.6589, train F loss: -0.1617, acc 0.9792
# epoch 208: train D loss: 0.6503, train F loss: -0.1459, acc 0.9764
# epoch 209: train D loss: 0.6566, train F loss: -0.1558, acc 0.9792
# epoch 210: train D loss: 0.6650, train F loss: -0.1390, acc 0.9720
# epoch 211: train D loss: 0.6605, train F loss: -0.1588, acc 0.9786
# epoch 212: train D loss: 0.6571, train F loss: -0.1513, acc 0.9740
# epoch 213: train D loss: 0.6551, train F loss: -0.1486, acc 0.9768
# epoch 214: train D loss: 0.6588, train F loss: -0.1558, acc 0.9758
# epoch 215: train D loss: 0.6548, train F loss: -0.1509, acc 0.9754
# epoch 216: train D loss: 0.6587, train F loss: -0.1595, acc 0.9778
# good
# epoch 217: train D loss: 0.6660, train F loss: -0.1750, acc 0.9812
# epoch 218: train D loss: 0.6494, train F loss: -0.1709, acc 0.9798
# epoch 219: train D loss: 0.6592, train F loss: -0.1709, acc 0.9802
# epoch 220: train D loss: 0.6784, train F loss: -0.1555, acc 0.9742
# epoch 221: train D loss: 0.6637, train F loss: -0.1712, acc 0.9790
# epoch 222: train D loss: 0.6637, train F loss: -0.1734, acc 0.9802
# epoch 223: train D loss: 0.6653, train F loss: -0.1696, acc 0.9770
# epoch 224: train D loss: 0.6584, train F loss: -0.1739, acc 0.9794
# epoch 225: train D loss: 0.6528, train F loss: -0.1614, acc 0.9772
# epoch 226: train D loss: 0.6627, train F loss: -0.1632, acc 0.9764
# good
# epoch 227: train D loss: 0.6500, train F loss: -0.1757, acc 0.9800
# epoch 228: train D loss: 0.6655, train F loss: -0.1571, acc 0.9722
# epoch 229: train D loss: 0.6688, train F loss: -0.1653, acc 0.9740
# good
# epoch 230: train D loss: 0.6704, train F loss: -0.1801, acc 0.9766
# good
# epoch 231: train D loss: 0.6514, train F loss: -0.1863, acc 0.9822
# epoch 232: train D loss: 0.6566, train F loss: -0.1776, acc 0.9776
# good
# epoch 233: train D loss: 0.6546, train F loss: -0.1872, acc 0.9800
# good
# epoch 234: train D loss: 0.6624, train F loss: -0.1877, acc 0.9808
# good
# epoch 235: train D loss: 0.6612, train F loss: -0.1985, acc 0.9830
# epoch 236: train D loss: 0.6564, train F loss: -0.1874, acc 0.9810
# epoch 237: train D loss: 0.6592, train F loss: -0.1937, acc 0.9812
# epoch 238: train D loss: 0.6575, train F loss: -0.1858, acc 0.9790
# epoch 239: train D loss: 0.6635, train F loss: -0.1808, acc 0.9764
# epoch 240: train D loss: 0.6648, train F loss: -0.1857, acc 0.9804
# epoch 241: train D loss: 0.6622, train F loss: -0.1903, acc 0.9806
# epoch 242: train D loss: 0.6699, train F loss: -0.1832, acc 0.9764
# epoch 243: train D loss: 0.6612, train F loss: -0.1932, acc 0.9808
# epoch 244: train D loss: 0.6775, train F loss: -0.1983, acc 0.9794
# epoch 245: train D loss: 0.6660, train F loss: -0.1831, acc 0.9776
# good
# epoch 246: train D loss: 0.6659, train F loss: -0.2028, acc 0.9794
# good
# epoch 247: train D loss: 0.6607, train F loss: -0.2046, acc 0.9818
# epoch 248: train D loss: 0.6559, train F loss: -0.1998, acc 0.9812
# epoch 249: train D loss: 0.6666, train F loss: -0.1993, acc 0.9786
# good
# epoch 250: train D loss: 0.6707, train F loss: -0.2055, acc 0.9788
# epoch 251: train D loss: 0.6599, train F loss: -0.2000, acc 0.9794
# epoch 252: train D loss: 0.6564, train F loss: -0.2050, acc 0.9824
# epoch 253: train D loss: 0.6647, train F loss: -0.1998, acc 0.9766
# epoch 254: train D loss: 0.6742, train F loss: -0.1949, acc 0.9760
# epoch 255: train D loss: 0.6651, train F loss: -0.2011, acc 0.9798
# epoch 256: train D loss: 0.6591, train F loss: -0.1954, acc 0.9768
# good
# epoch 257: train D loss: 0.6693, train F loss: -0.2204, acc 0.9820
# epoch 258: train D loss: 0.6622, train F loss: -0.2079, acc 0.9806
# epoch 259: train D loss: 0.6628, train F loss: -0.2034, acc 0.9776
# epoch 260: train D loss: 0.6592, train F loss: -0.2095, acc 0.9800
# epoch 261: train D loss: 0.6722, train F loss: -0.2183, acc 0.9806
# epoch 262: train D loss: 0.6769, train F loss: -0.2183, acc 0.9816
# good
# epoch 263: train D loss: 0.6650, train F loss: -0.2267, acc 0.9850
# epoch 264: train D loss: 0.6696, train F loss: -0.2226, acc 0.9818
# epoch 265: train D loss: 0.6592, train F loss: -0.2089, acc 0.9782
# epoch 266: train D loss: 0.6667, train F loss: -0.2195, acc 0.9820
# epoch 267: train D loss: 0.6649, train F loss: -0.2070, acc 0.9784
# good
# epoch 268: train D loss: 0.6690, train F loss: -0.2281, acc 0.9820
# epoch 269: train D loss: 0.6645, train F loss: -0.2262, acc 0.9818
# epoch 270: train D loss: 0.6640, train F loss: -0.2249, acc 0.9808
# epoch 271: train D loss: 0.6680, train F loss: -0.2256, acc 0.9802
# epoch 272: train D loss: 0.6698, train F loss: -0.2273, acc 0.9812
# good
# epoch 273: train D loss: 0.6601, train F loss: -0.2314, acc 0.9836
# good
# epoch 274: train D loss: 0.6642, train F loss: -0.2380, acc 0.9848
# epoch 275: train D loss: 0.6651, train F loss: -0.2353, acc 0.9824
# epoch 276: train D loss: 0.6743, train F loss: -0.2261, acc 0.9790
# epoch 277: train D loss: 0.6589, train F loss: -0.2290, acc 0.9826
# good
# epoch 278: train D loss: 0.6724, train F loss: -0.2490, acc 0.9844
# epoch 279: train D loss: 0.6651, train F loss: -0.2364, acc 0.9806
# epoch 280: train D loss: 0.6629, train F loss: -0.2359, acc 0.9824
# epoch 281: train D loss: 0.6756, train F loss: -0.2451, acc 0.9838
# epoch 282: train D loss: 0.6671, train F loss: -0.2453, acc 0.9858
# epoch 283: train D loss: 0.6696, train F loss: -0.2483, acc 0.9854
# epoch 284: train D loss: 0.6692, train F loss: -0.2369, acc 0.9818
# epoch 285: train D loss: 0.6736, train F loss: -0.2339, acc 0.9804
# epoch 286: train D loss: 0.6764, train F loss: -0.2370, acc 0.9796
# epoch 287: train D loss: 0.6618, train F loss: -0.2283, acc 0.9768
# epoch 288: train D loss: 0.6750, train F loss: -0.2385, acc 0.9814
# epoch 289: train D loss: 0.6670, train F loss: -0.2450, acc 0.9826
# good
# epoch 290: train D loss: 0.6682, train F loss: -0.2602, acc 0.9856
# epoch 291: train D loss: 0.6776, train F loss: -0.2554, acc 0.9842
# epoch 292: train D loss: 0.6627, train F loss: -0.2423, acc 0.9820
# epoch 293: train D loss: 0.6675, train F loss: -0.2563, acc 0.9834
# epoch 294: train D loss: 0.6723, train F loss: -0.2565, acc 0.9838
# epoch 295: train D loss: 0.6673, train F loss: -0.2441, acc 0.9792
# epoch 296: train D loss: 0.6674, train F loss: -0.2413, acc 0.9806
# epoch 297: train D loss: 0.6626, train F loss: -0.2416, acc 0.9808
# epoch 298: train D loss: 0.6607, train F loss: -0.2337, acc 0.9772
# epoch 299: train D loss: 0.6584, train F loss: -0.2552, acc 0.9826
# epoch 300: train D loss: 0.6717, train F loss: -0.2459, acc 0.9796
# epoch 301: train D loss: 0.6580, train F loss: -0.2494, acc 0.9800
# epoch 302: train D loss: 0.6694, train F loss: -0.2480, acc 0.9786
# epoch 303: train D loss: 0.6469, train F loss: -0.2513, acc 0.9836
# epoch 304: train D loss: 0.6721, train F loss: -0.2588, acc 0.9824
# good
# epoch 305: train D loss: 0.6731, train F loss: -0.2609, acc 0.9812
# good
# epoch 306: train D loss: 0.6646, train F loss: -0.2662, acc 0.9850
# good
# epoch 307: train D loss: 0.6740, train F loss: -0.2693, acc 0.9814
# good
# epoch 308: train D loss: 0.6726, train F loss: -0.2714, acc 0.9844
# epoch 309: train D loss: 0.6655, train F loss: -0.2713, acc 0.9836
# good
# epoch 310: train D loss: 0.6734, train F loss: -0.2749, acc 0.9856
# epoch 311: train D loss: 0.6610, train F loss: -0.2609, acc 0.9850
# epoch 312: train D loss: 0.6643, train F loss: -0.2435, acc 0.9772
# epoch 313: train D loss: 0.6729, train F loss: -0.2722, acc 0.9828
# epoch 314: train D loss: 0.6711, train F loss: -0.2730, acc 0.9824
# good
# epoch 315: train D loss: 0.6776, train F loss: -0.2858, acc 0.9864
# epoch 316: train D loss: 0.6764, train F loss: -0.2807, acc 0.9832
# epoch 317: train D loss: 0.6741, train F loss: -0.2798, acc 0.9858
# epoch 318: train D loss: 0.6694, train F loss: -0.2820, acc 0.9858
# epoch 319: train D loss: 0.6714, train F loss: -0.2773, acc 0.9840
# epoch 320: train D loss: 0.6673, train F loss: -0.2753, acc 0.9840
# epoch 321: train D loss: 0.6733, train F loss: -0.2765, acc 0.9818
# epoch 322: train D loss: 0.6724, train F loss: -0.2808, acc 0.9844
# epoch 323: train D loss: 0.6730, train F loss: -0.2749, acc 0.9822
# epoch 324: train D loss: 0.6706, train F loss: -0.2814, acc 0.9844
# good
# epoch 325: train D loss: 0.6702, train F loss: -0.2878, acc 0.9842
# good
# epoch 326: train D loss: 0.6694, train F loss: -0.2885, acc 0.9858
# epoch 327: train D loss: 0.6676, train F loss: -0.2840, acc 0.9842
# epoch 328: train D loss: 0.6696, train F loss: -0.2854, acc 0.9850
# good
# epoch 329: train D loss: 0.6763, train F loss: -0.2908, acc 0.9840
# epoch 330: train D loss: 0.6720, train F loss: -0.2763, acc 0.9828
# epoch 331: train D loss: 0.6658, train F loss: -0.2721, acc 0.9810
# good
# epoch 332: train D loss: 0.6780, train F loss: -0.2928, acc 0.9838
# epoch 333: train D loss: 0.6774, train F loss: -0.2838, acc 0.9816
# epoch 334: train D loss: 0.6684, train F loss: -0.2848, acc 0.9840
# good
# epoch 335: train D loss: 0.6719, train F loss: -0.3000, acc 0.9856
# epoch 336: train D loss: 0.6722, train F loss: -0.2977, acc 0.9852
# epoch 337: train D loss: 0.6639, train F loss: -0.2872, acc 0.9836
# epoch 338: train D loss: 0.6783, train F loss: -0.2990, acc 0.9842
# epoch 339: train D loss: 0.6663, train F loss: -0.2896, acc 0.9830
# good
# epoch 340: train D loss: 0.6772, train F loss: -0.3067, acc 0.9870
# epoch 341: train D loss: 0.6679, train F loss: -0.2925, acc 0.9830
# epoch 342: train D loss: 0.6709, train F loss: -0.2949, acc 0.9800
# epoch 343: train D loss: 0.6730, train F loss: -0.2970, acc 0.9828
# epoch 344: train D loss: 0.6660, train F loss: -0.2957, acc 0.9822
# epoch 345: train D loss: 0.6730, train F loss: -0.3050, acc 0.9852
# good
# epoch 346: train D loss: 0.6746, train F loss: -0.3068, acc 0.9856
# epoch 347: train D loss: 0.6734, train F loss: -0.3061, acc 0.9866
# epoch 348: train D loss: 0.6635, train F loss: -0.3003, acc 0.9854
# epoch 349: train D loss: 0.6730, train F loss: -0.2999, acc 0.9814
# epoch 350: train D loss: 0.6672, train F loss: -0.2962, acc 0.9836
# epoch 351: train D loss: 0.6814, train F loss: -0.2912, acc 0.9820
# epoch 352: train D loss: 0.6682, train F loss: -0.2815, acc 0.9776
# epoch 353: train D loss: 0.6715, train F loss: -0.3043, acc 0.9844
# good
# epoch 354: train D loss: 0.6665, train F loss: -0.3084, acc 0.9860
# good
# epoch 355: train D loss: 0.6653, train F loss: -0.3139, acc 0.9854
# epoch 356: train D loss: 0.6667, train F loss: -0.3100, acc 0.9840
# epoch 357: train D loss: 0.6785, train F loss: -0.3105, acc 0.9820
# epoch 358: train D loss: 0.6695, train F loss: -0.3037, acc 0.9818
# good
# epoch 359: train D loss: 0.6676, train F loss: -0.3183, acc 0.9860
# good
# epoch 360: train D loss: 0.6741, train F loss: -0.3217, acc 0.9884
# epoch 361: train D loss: 0.6685, train F loss: -0.3016, acc 0.9812
# epoch 362: train D loss: 0.6762, train F loss: -0.3110, acc 0.9812
# epoch 363: train D loss: 0.6713, train F loss: -0.3188, acc 0.9848
# epoch 364: train D loss: 0.6788, train F loss: -0.3133, acc 0.9808
# good
# epoch 365: train D loss: 0.6717, train F loss: -0.3274, acc 0.9874
# epoch 366: train D loss: 0.6689, train F loss: -0.3176, acc 0.9844
# epoch 367: train D loss: 0.6795, train F loss: -0.3244, acc 0.9856
# good
# epoch 368: train D loss: 0.6776, train F loss: -0.3274, acc 0.9838
# epoch 369: train D loss: 0.6749, train F loss: -0.3234, acc 0.9850
# epoch 370: train D loss: 0.6708, train F loss: -0.3115, acc 0.9838
# good
# epoch 371: train D loss: 0.6781, train F loss: -0.3310, acc 0.9850
# good
# epoch 372: train D loss: 0.6721, train F loss: -0.3312, acc 0.9862
# epoch 373: train D loss: 0.6721, train F loss: -0.3218, acc 0.9840
# epoch 374: train D loss: 0.6705, train F loss: -0.3232, acc 0.9838
# epoch 375: train D loss: 0.6655, train F loss: -0.3206, acc 0.9856
# epoch 376: train D loss: 0.6736, train F loss: -0.3240, acc 0.9846
# epoch 377: train D loss: 0.6693, train F loss: -0.3202, acc 0.9848
# epoch 378: train D loss: 0.6754, train F loss: -0.3307, acc 0.9832
# epoch 379: train D loss: 0.6695, train F loss: -0.3311, acc 0.9860
# good
# epoch 380: train D loss: 0.6729, train F loss: -0.3324, acc 0.9852
# good
# epoch 381: train D loss: 0.6789, train F loss: -0.3382, acc 0.9864
# good
# epoch 382: train D loss: 0.6698, train F loss: -0.3386, acc 0.9872
# good
# epoch 383: train D loss: 0.6755, train F loss: -0.3397, acc 0.9868
# epoch 384: train D loss: 0.6630, train F loss: -0.3270, acc 0.9840
# good
# epoch 385: train D loss: 0.6795, train F loss: -0.3405, acc 0.9836
# epoch 386: train D loss: 0.6768, train F loss: -0.3382, acc 0.9830
# epoch 387: train D loss: 0.6709, train F loss: -0.3378, acc 0.9878
# good
# epoch 388: train D loss: 0.6731, train F loss: -0.3494, acc 0.9882
# epoch 389: train D loss: 0.6631, train F loss: -0.3336, acc 0.9854
# epoch 390: train D loss: 0.6734, train F loss: -0.3323, acc 0.9822
# epoch 391: train D loss: 0.6798, train F loss: -0.3449, acc 0.9850
# epoch 392: train D loss: 0.6739, train F loss: -0.3473, acc 0.9878
# epoch 393: train D loss: 0.6720, train F loss: -0.3386, acc 0.9858
# epoch 394: train D loss: 0.6779, train F loss: -0.3437, acc 0.9848
# epoch 395: train D loss: 0.6756, train F loss: -0.3463, acc 0.9852
# epoch 396: train D loss: 0.6815, train F loss: -0.3491, acc 0.9854
# epoch 397: train D loss: 0.6696, train F loss: -0.3423, acc 0.9846
# good
# epoch 398: train D loss: 0.6755, train F loss: -0.3534, acc 0.9868
# epoch 399: train D loss: 0.6601, train F loss: -0.3374, acc 0.9832
# good
# epoch 400: train D loss: 0.6871, train F loss: -0.3590, acc 0.9868
# epoch 401: train D loss: 0.6628, train F loss: -0.3483, acc 0.9872
# good
# epoch 402: train D loss: 0.6867, train F loss: -0.3644, acc 0.9886
# epoch 403: train D loss: 0.6760, train F loss: -0.3552, acc 0.9874
# epoch 404: train D loss: 0.6746, train F loss: -0.3412, acc 0.9816
# epoch 405: train D loss: 0.6805, train F loss: -0.3544, acc 0.9844
# epoch 406: train D loss: 0.6716, train F loss: -0.3543, acc 0.9858
# epoch 407: train D loss: 0.6785, train F loss: -0.3591, acc 0.9874
# epoch 408: train D loss: 0.6642, train F loss: -0.3427, acc 0.9822
# good
# epoch 409: train D loss: 0.6782, train F loss: -0.3675, acc 0.9882
# epoch 410: train D loss: 0.6716, train F loss: -0.3583, acc 0.9850
# epoch 411: train D loss: 0.6763, train F loss: -0.3622, acc 0.9876
# epoch 412: train D loss: 0.6721, train F loss: -0.3441, acc 0.9822
# epoch 413: train D loss: 0.6721, train F loss: -0.3611, acc 0.9872
# epoch 414: train D loss: 0.6728, train F loss: -0.3612, acc 0.9844
# epoch 415: train D loss: 0.6814, train F loss: -0.3601, acc 0.9844
# epoch 416: train D loss: 0.6729, train F loss: -0.3646, acc 0.9868
# epoch 417: train D loss: 0.6765, train F loss: -0.3620, acc 0.9848
# epoch 418: train D loss: 0.6755, train F loss: -0.3644, acc 0.9854
# good
# epoch 419: train D loss: 0.6759, train F loss: -0.3680, acc 0.9862
# epoch 420: train D loss: 0.6725, train F loss: -0.3658, acc 0.9876
# epoch 421: train D loss: 0.6706, train F loss: -0.3537, acc 0.9834
# epoch 422: train D loss: 0.6668, train F loss: -0.3600, acc 0.9840
# epoch 423: train D loss: 0.6802, train F loss: -0.3640, acc 0.9820
# epoch 424: train D loss: 0.6709, train F loss: -0.3623, acc 0.9856
# epoch 425: train D loss: 0.6799, train F loss: -0.3640, acc 0.9836
# good
# epoch 426: train D loss: 0.6710, train F loss: -0.3796, acc 0.9894
# good
# epoch 427: train D loss: 0.6760, train F loss: -0.3797, acc 0.9884
# epoch 428: train D loss: 0.6702, train F loss: -0.3659, acc 0.9858
# epoch 429: train D loss: 0.6806, train F loss: -0.3759, acc 0.9866
# epoch 430: train D loss: 0.6708, train F loss: -0.3681, acc 0.9848
# epoch 431: train D loss: 0.6716, train F loss: -0.3660, acc 0.9842
# good
# epoch 432: train D loss: 0.6891, train F loss: -0.3834, acc 0.9860
# epoch 433: train D loss: 0.6695, train F loss: -0.3701, acc 0.9856
# epoch 434: train D loss: 0.6788, train F loss: -0.3776, acc 0.9858
# epoch 435: train D loss: 0.6810, train F loss: -0.3799, acc 0.9872
# epoch 436: train D loss: 0.6732, train F loss: -0.3817, acc 0.9872
# epoch 437: train D loss: 0.6822, train F loss: -0.3785, acc 0.9860
# epoch 438: train D loss: 0.6662, train F loss: -0.3617, acc 0.9868
# epoch 439: train D loss: 0.6782, train F loss: -0.3551, acc 0.9790
# good
# epoch 440: train D loss: 0.6758, train F loss: -0.3923, acc 0.9906
# epoch 441: train D loss: 0.6701, train F loss: -0.3865, acc 0.9888
# epoch 442: train D loss: 0.6771, train F loss: -0.3909, acc 0.9894
# epoch 443: train D loss: 0.6719, train F loss: -0.3919, acc 0.9898
# good
# epoch 444: train D loss: 0.6805, train F loss: -0.3946, acc 0.9906
# epoch 445: train D loss: 0.6723, train F loss: -0.3931, acc 0.9910
# epoch 446: train D loss: 0.6725, train F loss: -0.3817, acc 0.9864
# good
# epoch 447: train D loss: 0.6840, train F loss: -0.3981, acc 0.9890
# epoch 448: train D loss: 0.6893, train F loss: -0.3950, acc 0.9868
# epoch 449: train D loss: 0.6808, train F loss: -0.3944, acc 0.9884
# epoch 450: train D loss: 0.6772, train F loss: -0.3776, acc 0.9844
# epoch 451: train D loss: 0.6755, train F loss: -0.3938, acc 0.9886
# good
# epoch 452: train D loss: 0.6841, train F loss: -0.3993, acc 0.9876
# good
# epoch 453: train D loss: 0.6821, train F loss: -0.4016, acc 0.9906
# epoch 454: train D loss: 0.6791, train F loss: -0.3882, acc 0.9866
# epoch 455: train D loss: 0.6910, train F loss: -0.3943, acc 0.9824
# epoch 456: train D loss: 0.6814, train F loss: -0.3871, acc 0.9824
# epoch 457: train D loss: 0.6754, train F loss: -0.3961, acc 0.9882
# epoch 458: train D loss: 0.6928, train F loss: -0.3956, acc 0.9826
# epoch 459: train D loss: 0.6765, train F loss: -0.3983, acc 0.9886
# epoch 460: train D loss: 0.6799, train F loss: -0.3963, acc 0.9874
# epoch 461: train D loss: 0.6749, train F loss: -0.3962, acc 0.9876
# epoch 462: train D loss: 0.6746, train F loss: -0.3982, acc 0.9872
# good
# epoch 463: train D loss: 0.6813, train F loss: -0.4046, acc 0.9892
# epoch 464: train D loss: 0.6791, train F loss: -0.3992, acc 0.9866
# epoch 465: train D loss: 0.6781, train F loss: -0.3845, acc 0.9842
# epoch 466: train D loss: 0.6718, train F loss: -0.3810, acc 0.9818
# epoch 467: train D loss: 0.6753, train F loss: -0.3983, acc 0.9872
# epoch 468: train D loss: 0.6740, train F loss: -0.4033, acc 0.9880
# good
# epoch 469: train D loss: 0.6824, train F loss: -0.4104, acc 0.9876
# good
# epoch 470: train D loss: 0.6873, train F loss: -0.4115, acc 0.9858
# epoch 471: train D loss: 0.6768, train F loss: -0.4103, acc 0.9892
# epoch 472: train D loss: 0.6785, train F loss: -0.4103, acc 0.9886
# epoch 473: train D loss: 0.6752, train F loss: -0.4059, acc 0.9878
# epoch 474: train D loss: 0.6737, train F loss: -0.4014, acc 0.9870
# good
# epoch 475: train D loss: 0.6951, train F loss: -0.4258, acc 0.9894
# epoch 476: train D loss: 0.6760, train F loss: -0.4105, acc 0.9874
# epoch 477: train D loss: 0.6802, train F loss: -0.4210, acc 0.9892
# epoch 478: train D loss: 0.6818, train F loss: -0.4111, acc 0.9860
# epoch 479: train D loss: 0.6754, train F loss: -0.4146, acc 0.9892
# epoch 480: train D loss: 0.6746, train F loss: -0.4174, acc 0.9892
# epoch 481: train D loss: 0.6805, train F loss: -0.4182, acc 0.9894
# epoch 482: train D loss: 0.6773, train F loss: -0.4179, acc 0.9866
# epoch 483: train D loss: 0.6757, train F loss: -0.4097, acc 0.9878
# epoch 484: train D loss: 0.6770, train F loss: -0.4102, acc 0.9860
# epoch 485: train D loss: 0.6722, train F loss: -0.4122, acc 0.9886
# epoch 486: train D loss: 0.6776, train F loss: -0.4104, acc 0.9850
# epoch 487: train D loss: 0.6826, train F loss: -0.4128, acc 0.9842
# epoch 488: train D loss: 0.6819, train F loss: -0.4184, acc 0.9884
# epoch 489: train D loss: 0.6828, train F loss: -0.4185, acc 0.9852
# epoch 490: train D loss: 0.6759, train F loss: -0.4108, acc 0.9838
# epoch 491: train D loss: 0.6775, train F loss: -0.4156, acc 0.9868
# epoch 492: train D loss: 0.6818, train F loss: -0.4244, acc 0.9874
# epoch 493: train D loss: 0.6758, train F loss: -0.4202, acc 0.9878
# epoch 494: train D loss: 0.6812, train F loss: -0.4129, acc 0.9830
# epoch 495: train D loss: 0.6770, train F loss: -0.4153, acc 0.9866
# epoch 496: train D loss: 0.6746, train F loss: -0.4228, acc 0.9890
# epoch 497: train D loss: 0.6824, train F loss: -0.4191, acc 0.9840
# epoch 498: train D loss: 0.6758, train F loss: -0.4192, acc 0.9862
# epoch 499: train D loss: 0.6738, train F loss: -0.4253, acc 0.9888
# epoch 500: train D loss: 0.6779, train F loss: -0.4228, acc 0.9872
# epoch 501: train D loss: 0.6740, train F loss: -0.4253, acc 0.9888
# good
# epoch 502: train D loss: 0.6843, train F loss: -0.4381, acc 0.9910
# epoch 503: train D loss: 0.6716, train F loss: -0.4265, acc 0.9888
# epoch 504: train D loss: 0.6779, train F loss: -0.4284, acc 0.9880
# epoch 505: train D loss: 0.6750, train F loss: -0.4226, acc 0.9866
# epoch 506: train D loss: 0.6858, train F loss: -0.4352, acc 0.9884
# epoch 507: train D loss: 0.6805, train F loss: -0.4270, acc 0.9890
# epoch 508: train D loss: 0.6746, train F loss: -0.4185, acc 0.9854
# epoch 509: train D loss: 0.6813, train F loss: -0.4146, acc 0.9812
# epoch 510: train D loss: 0.6757, train F loss: -0.4268, acc 0.9880
# epoch 511: train D loss: 0.6820, train F loss: -0.4252, acc 0.9842
# epoch 512: train D loss: 0.6760, train F loss: -0.4358, acc 0.9884
# epoch 513: train D loss: 0.6740, train F loss: -0.4238, acc 0.9868
# epoch 514: train D loss: 0.6767, train F loss: -0.4331, acc 0.9878
# epoch 515: train D loss: 0.6795, train F loss: -0.4359, acc 0.9892
# epoch 516: train D loss: 0.6707, train F loss: -0.4311, acc 0.9886
# good
# epoch 517: train D loss: 0.6875, train F loss: -0.4405, acc 0.9888
# epoch 518: train D loss: 0.6773, train F loss: -0.4367, acc 0.9894
# good
# epoch 519: train D loss: 0.6820, train F loss: -0.4424, acc 0.9888
# epoch 520: train D loss: 0.6752, train F loss: -0.4403, acc 0.9884
# epoch 521: train D loss: 0.6776, train F loss: -0.4415, acc 0.9880
# good
# epoch 522: train D loss: 0.6832, train F loss: -0.4497, acc 0.9906
# epoch 523: train D loss: 0.6812, train F loss: -0.4419, acc 0.9894
# good
# epoch 524: train D loss: 0.6863, train F loss: -0.4529, acc 0.9904
# epoch 525: train D loss: 0.6818, train F loss: -0.4487, acc 0.9888
# epoch 526: train D loss: 0.6722, train F loss: -0.4338, acc 0.9860
# epoch 527: train D loss: 0.6770, train F loss: -0.4439, acc 0.9878
# epoch 528: train D loss: 0.6779, train F loss: -0.4429, acc 0.9878
# epoch 529: train D loss: 0.6738, train F loss: -0.4406, acc 0.9876
# epoch 530: train D loss: 0.6903, train F loss: -0.4508, acc 0.9876
# epoch 531: train D loss: 0.6731, train F loss: -0.4403, acc 0.9884
# epoch 532: train D loss: 0.6830, train F loss: -0.4440, acc 0.9846
# epoch 533: train D loss: 0.6874, train F loss: -0.4478, acc 0.9890
# epoch 534: train D loss: 0.6756, train F loss: -0.4442, acc 0.9886
# epoch 535: train D loss: 0.6776, train F loss: -0.4516, acc 0.9900
# epoch 536: train D loss: 0.6821, train F loss: -0.4461, acc 0.9884
# epoch 537: train D loss: 0.6790, train F loss: -0.4516, acc 0.9898
# epoch 538: train D loss: 0.6807, train F loss: -0.4391, acc 0.9848
# epoch 539: train D loss: 0.6787, train F loss: -0.4512, acc 0.9896
# epoch 540: train D loss: 0.6870, train F loss: -0.4445, acc 0.9840
# epoch 541: train D loss: 0.6806, train F loss: -0.4521, acc 0.9880
# good
# epoch 542: train D loss: 0.6816, train F loss: -0.4575, acc 0.9914
# epoch 543: train D loss: 0.6806, train F loss: -0.4540, acc 0.9884
# epoch 544: train D loss: 0.6800, train F loss: -0.4573, acc 0.9888
# epoch 545: train D loss: 0.6746, train F loss: -0.4474, acc 0.9870
# epoch 546: train D loss: 0.6818, train F loss: -0.4423, acc 0.9868
# epoch 547: train D loss: 0.6802, train F loss: -0.4505, acc 0.9872
# epoch 548: train D loss: 0.6782, train F loss: -0.4517, acc 0.9880
# epoch 549: train D loss: 0.6795, train F loss: -0.4567, acc 0.9866
# epoch 550: train D loss: 0.6779, train F loss: -0.4495, acc 0.9864
# epoch 551: train D loss: 0.6797, train F loss: -0.4441, acc 0.9830
# epoch 552: train D loss: 0.6778, train F loss: -0.4474, acc 0.9864
# epoch 553: train D loss: 0.6796, train F loss: -0.4461, acc 0.9852
# good
# epoch 554: train D loss: 0.6754, train F loss: -0.4594, acc 0.9894
# good
# epoch 555: train D loss: 0.6799, train F loss: -0.4702, acc 0.9916
# epoch 556: train D loss: 0.6831, train F loss: -0.4691, acc 0.9904
# epoch 557: train D loss: 0.6724, train F loss: -0.4573, acc 0.9894
# epoch 558: train D loss: 0.6795, train F loss: -0.4592, acc 0.9890
# epoch 559: train D loss: 0.6763, train F loss: -0.4538, acc 0.9854
# good
# epoch 560: train D loss: 0.6851, train F loss: -0.4725, acc 0.9918
# epoch 561: train D loss: 0.6817, train F loss: -0.4645, acc 0.9874
# epoch 562: train D loss: 0.6799, train F loss: -0.4658, acc 0.9892
# epoch 563: train D loss: 0.6832, train F loss: -0.4616, acc 0.9868
# epoch 564: train D loss: 0.6730, train F loss: -0.4602, acc 0.9884
# epoch 565: train D loss: 0.6763, train F loss: -0.4635, acc 0.9896
# epoch 566: train D loss: 0.6829, train F loss: -0.4629, acc 0.9866
# epoch 567: train D loss: 0.6751, train F loss: -0.4617, acc 0.9880
# epoch 568: train D loss: 0.6759, train F loss: -0.4604, acc 0.9894
# epoch 569: train D loss: 0.6791, train F loss: -0.4558, acc 0.9862
# epoch 570: train D loss: 0.6781, train F loss: -0.4649, acc 0.9904
# epoch 571: train D loss: 0.6783, train F loss: -0.4598, acc 0.9872
# epoch 572: train D loss: 0.6717, train F loss: -0.4724, acc 0.9908
# epoch 573: train D loss: 0.6806, train F loss: -0.4716, acc 0.9888
# epoch 574: train D loss: 0.6797, train F loss: -0.4717, acc 0.9892
# epoch 575: train D loss: 0.6774, train F loss: -0.4709, acc 0.9892
# epoch 576: train D loss: 0.6815, train F loss: -0.4667, acc 0.9862
# good
# epoch 577: train D loss: 0.6822, train F loss: -0.4744, acc 0.9898
# epoch 578: train D loss: 0.6801, train F loss: -0.4690, acc 0.9872
# epoch 579: train D loss: 0.6699, train F loss: -0.4567, acc 0.9884
# epoch 580: train D loss: 0.6804, train F loss: -0.4710, acc 0.9876
# epoch 581: train D loss: 0.6756, train F loss: -0.4658, acc 0.9894
# epoch 582: train D loss: 0.6745, train F loss: -0.4741, acc 0.9908
# good
# epoch 583: train D loss: 0.6831, train F loss: -0.4809, acc 0.9892
# epoch 584: train D loss: 0.6820, train F loss: -0.4647, acc 0.9844
# epoch 585: train D loss: 0.6781, train F loss: -0.4737, acc 0.9886
# good
# epoch 586: train D loss: 0.6871, train F loss: -0.4811, acc 0.9884
# good
# epoch 587: train D loss: 0.6803, train F loss: -0.4831, acc 0.9904
# epoch 588: train D loss: 0.6809, train F loss: -0.4788, acc 0.9888
# epoch 589: train D loss: 0.6786, train F loss: -0.4807, acc 0.9902
# epoch 590: train D loss: 0.6772, train F loss: -0.4645, acc 0.9858
# epoch 591: train D loss: 0.6795, train F loss: -0.4749, acc 0.9868
# epoch 592: train D loss: 0.6765, train F loss: -0.4782, acc 0.9894
# epoch 593: train D loss: 0.6782, train F loss: -0.4760, acc 0.9880
# good
# epoch 594: train D loss: 0.6781, train F loss: -0.4865, acc 0.9912
# good
# epoch 595: train D loss: 0.6801, train F loss: -0.4896, acc 0.9916
# epoch 596: train D loss: 0.6775, train F loss: -0.4775, acc 0.9886
# epoch 597: train D loss: 0.6821, train F loss: -0.4847, acc 0.9898
# epoch 598: train D loss: 0.6823, train F loss: -0.4885, acc 0.9894
# good
# epoch 599: train D loss: 0.6796, train F loss: -0.4917, acc 0.9902
# epoch 600: train D loss: 0.6793, train F loss: -0.4803, acc 0.9890
# epoch 601: train D loss: 0.6840, train F loss: -0.4865, acc 0.9886
# epoch 602: train D loss: 0.6820, train F loss: -0.4811, acc 0.9892
# epoch 603: train D loss: 0.6806, train F loss: -0.4819, acc 0.9874
# epoch 604: train D loss: 0.6759, train F loss: -0.4887, acc 0.9898
# epoch 605: train D loss: 0.6809, train F loss: -0.4911, acc 0.9900
# epoch 606: train D loss: 0.6779, train F loss: -0.4885, acc 0.9916
# good
# epoch 607: train D loss: 0.6808, train F loss: -0.4955, acc 0.9904
# epoch 608: train D loss: 0.6779, train F loss: -0.4906, acc 0.9900
# epoch 609: train D loss: 0.6806, train F loss: -0.4871, acc 0.9884
# epoch 610: train D loss: 0.6792, train F loss: -0.4802, acc 0.9872
# epoch 611: train D loss: 0.6772, train F loss: -0.4831, acc 0.9870
# epoch 612: train D loss: 0.6802, train F loss: -0.4896, acc 0.9888
# epoch 613: train D loss: 0.6837, train F loss: -0.4938, acc 0.9896
# epoch 614: train D loss: 0.6760, train F loss: -0.4841, acc 0.9870
# epoch 615: train D loss: 0.6812, train F loss: -0.4953, acc 0.9896
# epoch 616: train D loss: 0.6817, train F loss: -0.4942, acc 0.9896
# epoch 617: train D loss: 0.6797, train F loss: -0.4895, acc 0.9878
# good
# epoch 618: train D loss: 0.6851, train F loss: -0.5002, acc 0.9898
# epoch 619: train D loss: 0.6797, train F loss: -0.4924, acc 0.9882
# epoch 620: train D loss: 0.6772, train F loss: -0.4970, acc 0.9906
# epoch 621: train D loss: 0.6856, train F loss: -0.4773, acc 0.9850
# epoch 622: train D loss: 0.6789, train F loss: -0.4721, acc 0.9836
# epoch 623: train D loss: 0.6890, train F loss: -0.4964, acc 0.9872
# epoch 624: train D loss: 0.6801, train F loss: -0.4947, acc 0.9890
# epoch 625: train D loss: 0.6849, train F loss: -0.4981, acc 0.9886
# good
# epoch 626: train D loss: 0.6839, train F loss: -0.5066, acc 0.9918
# epoch 627: train D loss: 0.6819, train F loss: -0.4943, acc 0.9882
# epoch 628: train D loss: 0.6857, train F loss: -0.4998, acc 0.9886
# epoch 629: train D loss: 0.6756, train F loss: -0.4973, acc 0.9896
# good
# epoch 630: train D loss: 0.6824, train F loss: -0.5066, acc 0.9912
# epoch 631: train D loss: 0.6844, train F loss: -0.5054, acc 0.9902
# epoch 632: train D loss: 0.6828, train F loss: -0.4946, acc 0.9882
# epoch 633: train D loss: 0.6833, train F loss: -0.4966, acc 0.9870
# epoch 634: train D loss: 0.6739, train F loss: -0.4986, acc 0.9900
# epoch 635: train D loss: 0.6851, train F loss: -0.5043, acc 0.9898
# good
# epoch 636: train D loss: 0.6819, train F loss: -0.5072, acc 0.9902
# epoch 637: train D loss: 0.6807, train F loss: -0.4992, acc 0.9892
# good
# epoch 638: train D loss: 0.6837, train F loss: -0.5086, acc 0.9916
# epoch 639: train D loss: 0.6780, train F loss: -0.5049, acc 0.9922
# epoch 640: train D loss: 0.6854, train F loss: -0.4968, acc 0.9880
# epoch 641: train D loss: 0.6861, train F loss: -0.4966, acc 0.9866
# epoch 642: train D loss: 0.6811, train F loss: -0.5000, acc 0.9870
# epoch 643: train D loss: 0.6747, train F loss: -0.5028, acc 0.9894
# good
# epoch 644: train D loss: 0.6852, train F loss: -0.5087, acc 0.9890
# epoch 645: train D loss: 0.6774, train F loss: -0.5064, acc 0.9912
# good
# epoch 646: train D loss: 0.6797, train F loss: -0.5110, acc 0.9908
# epoch 647: train D loss: 0.6780, train F loss: -0.5040, acc 0.9896
# good
# epoch 648: train D loss: 0.6870, train F loss: -0.5156, acc 0.9892
# epoch 649: train D loss: 0.6863, train F loss: -0.5118, acc 0.9898
# epoch 650: train D loss: 0.6824, train F loss: -0.5113, acc 0.9912
# good
# epoch 651: train D loss: 0.6848, train F loss: -0.5171, acc 0.9926
# epoch 652: train D loss: 0.6834, train F loss: -0.5122, acc 0.9906
# epoch 653: train D loss: 0.6820, train F loss: -0.5037, acc 0.9872
# epoch 654: train D loss: 0.6796, train F loss: -0.5094, acc 0.9902
# epoch 655: train D loss: 0.6774, train F loss: -0.5088, acc 0.9888
# good
# epoch 656: train D loss: 0.6900, train F loss: -0.5198, acc 0.9894
# epoch 657: train D loss: 0.6847, train F loss: -0.5148, acc 0.9874
# epoch 658: train D loss: 0.6764, train F loss: -0.5074, acc 0.9900
# epoch 659: train D loss: 0.6897, train F loss: -0.5186, acc 0.9898
# epoch 660: train D loss: 0.6780, train F loss: -0.5110, acc 0.9886
# epoch 661: train D loss: 0.6785, train F loss: -0.5080, acc 0.9884
# epoch 662: train D loss: 0.6854, train F loss: -0.5141, acc 0.9884
# epoch 663: train D loss: 0.6838, train F loss: -0.5162, acc 0.9890
# epoch 664: train D loss: 0.6724, train F loss: -0.5067, acc 0.9900
# good
# epoch 665: train D loss: 0.6878, train F loss: -0.5208, acc 0.9898
# epoch 666: train D loss: 0.6782, train F loss: -0.5093, acc 0.9880
# good
# epoch 667: train D loss: 0.6770, train F loss: -0.5221, acc 0.9912
# epoch 668: train D loss: 0.6826, train F loss: -0.5164, acc 0.9890
# epoch 669: train D loss: 0.6804, train F loss: -0.5178, acc 0.9908
# epoch 670: train D loss: 0.6819, train F loss: -0.5190, acc 0.9898
# epoch 671: train D loss: 0.6799, train F loss: -0.5171, acc 0.9900
# good
# epoch 672: train D loss: 0.6860, train F loss: -0.5223, acc 0.9894
# good
# epoch 673: train D loss: 0.6831, train F loss: -0.5236, acc 0.9916
# good
# epoch 674: train D loss: 0.6844, train F loss: -0.5248, acc 0.9920
# good
# epoch 675: train D loss: 0.6850, train F loss: -0.5293, acc 0.9916
# epoch 676: train D loss: 0.6820, train F loss: -0.5230, acc 0.9902
# epoch 677: train D loss: 0.6816, train F loss: -0.5144, acc 0.9896
# epoch 678: train D loss: 0.6850, train F loss: -0.5174, acc 0.9858
# epoch 679: train D loss: 0.6806, train F loss: -0.5138, acc 0.9874
# epoch 680: train D loss: 0.6767, train F loss: -0.5091, acc 0.9864
# epoch 681: train D loss: 0.6820, train F loss: -0.5134, acc 0.9862
# epoch 682: train D loss: 0.6858, train F loss: -0.5272, acc 0.9906
# epoch 683: train D loss: 0.6821, train F loss: -0.5277, acc 0.9908
# epoch 684: train D loss: 0.6722, train F loss: -0.5199, acc 0.9906
# epoch 685: train D loss: 0.6830, train F loss: -0.5265, acc 0.9906
# epoch 686: train D loss: 0.6728, train F loss: -0.5142, acc 0.9890
# epoch 687: train D loss: 0.6749, train F loss: -0.5249, acc 0.9926
# good
# epoch 688: train D loss: 0.6850, train F loss: -0.5308, acc 0.9916
# good
# epoch 689: train D loss: 0.6879, train F loss: -0.5331, acc 0.9912
# epoch 690: train D loss: 0.6846, train F loss: -0.5322, acc 0.9914
# epoch 691: train D loss: 0.6840, train F loss: -0.5262, acc 0.9894
# epoch 692: train D loss: 0.6898, train F loss: -0.5309, acc 0.9876
# epoch 693: train D loss: 0.6776, train F loss: -0.5269, acc 0.9912
# epoch 694: train D loss: 0.6760, train F loss: -0.5242, acc 0.9906
# good
# epoch 695: train D loss: 0.6887, train F loss: -0.5339, acc 0.9904
# epoch 696: train D loss: 0.6827, train F loss: -0.5291, acc 0.9904
# epoch 697: train D loss: 0.6798, train F loss: -0.5238, acc 0.9874
# good
# epoch 698: train D loss: 0.6919, train F loss: -0.5397, acc 0.9890
# epoch 699: train D loss: 0.6812, train F loss: -0.5333, acc 0.9906
# epoch 700: train D loss: 0.6828, train F loss: -0.5286, acc 0.9894
# epoch 701: train D loss: 0.6866, train F loss: -0.5377, acc 0.9900
# epoch 702: train D loss: 0.6815, train F loss: -0.5296, acc 0.9908
# ...
# epoch 2765: train D loss: 0.6872, train F loss: -0.6740, acc 0.9948
# epoch 2766: train D loss: 0.6878, train F loss: -0.6757, acc 0.9956
# epoch 2767: train D loss: 0.6911, train F loss: -0.6793, acc 0.9956
# epoch 2768: train D loss: 0.6900, train F loss: -0.6763, acc 0.9944
# epoch 2769: train D loss: 0.6874, train F loss: -0.6739, acc 0.9954
# epoch 2770: train D loss: 0.6899, train F loss: -0.6681, acc 0.9920
# epoch 2771: train D loss: 0.6851, train F loss: -0.6689, acc 0.9958
# epoch 2772: train D loss: 0.6902, train F loss: -0.6722, acc 0.9944
# epoch 2773: train D loss: 0.6892, train F loss: -0.6700, acc 0.9950
# epoch 2774: train D loss: 0.6925, train F loss: -0.6795, acc 0.9960
# epoch 2775: train D loss: 0.6882, train F loss: -0.6694, acc 0.9934
# epoch 2776: train D loss: 0.6909, train F loss: -0.6767, acc 0.9956
# epoch 2777: train D loss: 0.6839, train F loss: -0.6716, acc 0.9962
# epoch 2778: train D loss: 0.6916, train F loss: -0.6782, acc 0.9958
# epoch 2779: train D loss: 0.6870, train F loss: -0.6721, acc 0.9948
# epoch 2780: train D loss: 0.6911, train F loss: -0.6746, acc 0.9954
# epoch 2781: train D loss: 0.6900, train F loss: -0.6794, acc 0.9964
# epoch 2782: train D loss: 0.6919, train F loss: -0.6780, acc 0.9952
# epoch 2783: train D loss: 0.6891, train F loss: -0.6763, acc 0.9950
# epoch 2784: train D loss: 0.6892, train F loss: -0.6791, acc 0.9968
# epoch 2785: train D loss: 0.6949, train F loss: -0.6782, acc 0.9958
# epoch 2786: train D loss: 0.6859, train F loss: -0.6673, acc 0.9950
# epoch 2787: train D loss: 0.6881, train F loss: -0.6710, acc 0.9946
# epoch 2788: train D loss: 0.6912, train F loss: -0.6788, acc 0.9950
# epoch 2789: train D loss: 0.6888, train F loss: -0.6614, acc 0.9950
# epoch 2790: train D loss: 0.6883, train F loss: -0.6690, acc 0.9932
# epoch 2791: train D loss: 0.6875, train F loss: -0.6687, acc 0.9936
# epoch 2792: train D loss: 0.6880, train F loss: -0.6735, acc 0.9956
# epoch 2793: train D loss: 0.6889, train F loss: -0.6727, acc 0.9946
# epoch 2794: train D loss: 0.6898, train F loss: -0.6686, acc 0.9960
# epoch 2795: train D loss: 0.6883, train F loss: -0.6614, acc 0.9952
# epoch 2796: train D loss: 0.6876, train F loss: -0.6588, acc 0.9932
# epoch 2797: train D loss: 0.6866, train F loss: -0.6639, acc 0.9934
# epoch 2798: train D loss: 0.6868, train F loss: -0.6753, acc 0.9954
# epoch 2799: train D loss: 0.6868, train F loss: -0.6753, acc 0.9958
# epoch 2800: train D loss: 0.6874, train F loss: -0.6741, acc 0.9956
# epoch 2801: train D loss: 0.6883, train F loss: -0.6751, acc 0.9954
# epoch 2802: train D loss: 0.6908, train F loss: -0.6769, acc 0.9948
# epoch 2803: train D loss: 0.6861, train F loss: -0.6665, acc 0.9940
# epoch 2804: train D loss: 0.6951, train F loss: -0.6816, acc 0.9958
# epoch 2805: train D loss: 0.6901, train F loss: -0.6791, acc 0.9966
# epoch 2806: train D loss: 0.6902, train F loss: -0.6794, acc 0.9966
# epoch 2807: train D loss: 0.6886, train F loss: -0.6765, acc 0.9958
# epoch 2808: train D loss: 0.6913, train F loss: -0.6711, acc 0.9952
# epoch 2809: train D loss: 0.6940, train F loss: -0.6785, acc 0.9948
# epoch 2810: train D loss: 0.6889, train F loss: -0.6725, acc 0.9936
# epoch 2811: train D loss: 0.6889, train F loss: -0.6760, acc 0.9960
# epoch 2812: train D loss: 0.6903, train F loss: -0.6770, acc 0.9948
# epoch 2813: train D loss: 0.6906, train F loss: -0.6742, acc 0.9944
# epoch 2814: train D loss: 0.6903, train F loss: -0.6761, acc 0.9952
# epoch 2815: train D loss: 0.6905, train F loss: -0.6768, acc 0.9956
# epoch 2816: train D loss: 0.6891, train F loss: -0.6767, acc 0.9960
# epoch 2817: train D loss: 0.6904, train F loss: -0.6735, acc 0.9946
# epoch 2818: train D loss: 0.6880, train F loss: -0.6699, acc 0.9940
# epoch 2819: train D loss: 0.6892, train F loss: -0.6786, acc 0.9964
# epoch 2820: train D loss: 0.6907, train F loss: -0.6771, acc 0.9960
# epoch 2821: train D loss: 0.6904, train F loss: -0.6787, acc 0.9960
# epoch 2822: train D loss: 0.6879, train F loss: -0.6761, acc 0.9964
# epoch 2823: train D loss: 0.6889, train F loss: -0.6760, acc 0.9950
# epoch 2824: train D loss: 0.6914, train F loss: -0.6804, acc 0.9958
# epoch 2825: train D loss: 0.6884, train F loss: -0.6747, acc 0.9952
# epoch 2826: train D loss: 0.6882, train F loss: -0.6743, acc 0.9952
# epoch 2827: train D loss: 0.6902, train F loss: -0.6764, acc 0.9962
# epoch 2828: train D loss: 0.6905, train F loss: -0.6756, acc 0.9952
# epoch 2829: train D loss: 0.6875, train F loss: -0.6748, acc 0.9960
# epoch 2830: train D loss: 0.6926, train F loss: -0.6789, acc 0.9952
# epoch 2831: train D loss: 0.6924, train F loss: -0.6768, acc 0.9952
# epoch 2832: train D loss: 0.6917, train F loss: -0.6757, acc 0.9946
# epoch 2833: train D loss: 0.6875, train F loss: -0.6696, acc 0.9940
# epoch 2834: train D loss: 0.6915, train F loss: -0.6797, acc 0.9958
# epoch 2835: train D loss: 0.6899, train F loss: -0.6778, acc 0.9960
# epoch 2836: train D loss: 0.6889, train F loss: -0.6715, acc 0.9938
# epoch 2837: train D loss: 0.6914, train F loss: -0.6766, acc 0.9946
# epoch 2838: train D loss: 0.6889, train F loss: -0.6748, acc 0.9954
# epoch 2839: train D loss: 0.6926, train F loss: -0.6754, acc 0.9950
# epoch 2840: train D loss: 0.6884, train F loss: -0.6745, acc 0.9964
# epoch 2841: train D loss: 0.6902, train F loss: -0.6753, acc 0.9944
# epoch 2842: train D loss: 0.6907, train F loss: -0.6736, acc 0.9952
# epoch 2843: train D loss: 0.6877, train F loss: -0.6761, acc 0.9956
# epoch 2844: train D loss: 0.6920, train F loss: -0.6787, acc 0.9954
# epoch 2845: train D loss: 0.6854, train F loss: -0.6657, acc 0.9940
# epoch 2846: train D loss: 0.6927, train F loss: -0.6784, acc 0.9954
# epoch 2847: train D loss: 0.6897, train F loss: -0.6764, acc 0.9954
# epoch 2848: train D loss: 0.6927, train F loss: -0.6806, acc 0.9960
# epoch 2849: train D loss: 0.6926, train F loss: -0.6794, acc 0.9948
# epoch 2850: train D loss: 0.6885, train F loss: -0.6734, acc 0.9944
# epoch 2851: train D loss: 0.6913, train F loss: -0.6790, acc 0.9948
# epoch 2852: train D loss: 0.6880, train F loss: -0.6739, acc 0.9960
# epoch 2853: train D loss: 0.6905, train F loss: -0.6708, acc 0.9946
# epoch 2854: train D loss: 0.6883, train F loss: -0.6730, acc 0.9942
# epoch 2855: train D loss: 0.6863, train F loss: -0.6686, acc 0.9944
# epoch 2856: train D loss: 0.6887, train F loss: -0.6746, acc 0.9958
# epoch 2857: train D loss: 0.6897, train F loss: -0.6754, acc 0.9948
# epoch 2858: train D loss: 0.6909, train F loss: -0.6813, acc 0.9970
# epoch 2859: train D loss: 0.6882, train F loss: -0.6740, acc 0.9944
# epoch 2860: train D loss: 0.6923, train F loss: -0.6786, acc 0.9952
# epoch 2861: train D loss: 0.6886, train F loss: -0.6778, acc 0.9962
# epoch 2862: train D loss: 0.6898, train F loss: -0.6782, acc 0.9960
# epoch 2863: train D loss: 0.6915, train F loss: -0.6736, acc 0.9950
# epoch 2864: train D loss: 0.6913, train F loss: -0.6788, acc 0.9960
# epoch 2865: train D loss: 0.6859, train F loss: -0.6657, acc 0.9932
# epoch 2866: train D loss: 0.6905, train F loss: -0.6760, acc 0.9960
# epoch 2867: train D loss: 0.6845, train F loss: -0.6721, acc 0.9962
# epoch 2868: train D loss: 0.6935, train F loss: -0.6811, acc 0.9954
# epoch 2869: train D loss: 0.6923, train F loss: -0.6764, acc 0.9946
# epoch 2870: train D loss: 0.6857, train F loss: -0.6697, acc 0.9944
# epoch 2871: train D loss: 0.6922, train F loss: -0.6797, acc 0.9958
# epoch 2872: train D loss: 0.6921, train F loss: -0.6819, acc 0.9962
# epoch 2873: train D loss: 0.6915, train F loss: -0.6810, acc 0.9958
# epoch 2874: train D loss: 0.6910, train F loss: -0.6782, acc 0.9954
# epoch 2875: train D loss: 0.6913, train F loss: -0.6748, acc 0.9960
# epoch 2876: train D loss: 0.6887, train F loss: -0.6755, acc 0.9958
# epoch 2877: train D loss: 0.6875, train F loss: -0.6751, acc 0.9962
# epoch 2878: train D loss: 0.6898, train F loss: -0.6759, acc 0.9958
# epoch 2879: train D loss: 0.6902, train F loss: -0.6747, acc 0.9948
# epoch 2880: train D loss: 0.6905, train F loss: -0.6784, acc 0.9962
# epoch 2881: train D loss: 0.6886, train F loss: -0.6751, acc 0.9958
# epoch 2882: train D loss: 0.6915, train F loss: -0.6770, acc 0.9948
# epoch 2883: train D loss: 0.6888, train F loss: -0.6753, acc 0.9960
# epoch 2884: train D loss: 0.6853, train F loss: -0.6586, acc 0.9936
# epoch 2885: train D loss: 0.6863, train F loss: -0.6671, acc 0.9938
# epoch 2886: train D loss: 0.6873, train F loss: -0.6716, acc 0.9942
# epoch 2887: train D loss: 0.6924, train F loss: -0.6781, acc 0.9952
# epoch 2888: train D loss: 0.6860, train F loss: -0.6714, acc 0.9948
# epoch 2889: train D loss: 0.6909, train F loss: -0.6768, acc 0.9952
# epoch 2890: train D loss: 0.6905, train F loss: -0.6770, acc 0.9958
# epoch 2891: train D loss: 0.6863, train F loss: -0.6762, acc 0.9964
# epoch 2892: train D loss: 0.6893, train F loss: -0.6748, acc 0.9954
# epoch 2893: train D loss: 0.6923, train F loss: -0.6758, acc 0.9934
# epoch 2894: train D loss: 0.6868, train F loss: -0.6684, acc 0.9952
# epoch 2895: train D loss: 0.6890, train F loss: -0.6737, acc 0.9960
# epoch 2896: train D loss: 0.6893, train F loss: -0.6736, acc 0.9948
# epoch 2897: train D loss: 0.6860, train F loss: -0.6734, acc 0.9958
# epoch 2898: train D loss: 0.6889, train F loss: -0.6739, acc 0.9952
# epoch 2899: train D loss: 0.6896, train F loss: -0.6781, acc 0.9962
# epoch 2900: train D loss: 0.6908, train F loss: -0.6777, acc 0.9956
# epoch 2901: train D loss: 0.6887, train F loss: -0.6729, acc 0.9956
# epoch 2902: train D loss: 0.6895, train F loss: -0.6779, acc 0.9966
# epoch 2903: train D loss: 0.6873, train F loss: -0.6764, acc 0.9964
# epoch 2904: train D loss: 0.6891, train F loss: -0.6759, acc 0.9956
# epoch 2905: train D loss: 0.6918, train F loss: -0.6752, acc 0.9942
# epoch 2906: train D loss: 0.6877, train F loss: -0.6739, acc 0.9956
# epoch 2907: train D loss: 0.6855, train F loss: -0.6676, acc 0.9962
# epoch 2908: train D loss: 0.6916, train F loss: -0.6748, acc 0.9946
# epoch 2909: train D loss: 0.6884, train F loss: -0.6709, acc 0.9944
# epoch 2910: train D loss: 0.6875, train F loss: -0.6734, acc 0.9950
# epoch 2911: train D loss: 0.6881, train F loss: -0.6748, acc 0.9958
# epoch 2912: train D loss: 0.6901, train F loss: -0.6766, acc 0.9954
# epoch 2913: train D loss: 0.6882, train F loss: -0.6743, acc 0.9956
# epoch 2914: train D loss: 0.6887, train F loss: -0.6758, acc 0.9952
# epoch 2915: train D loss: 0.6875, train F loss: -0.6740, acc 0.9944
# epoch 2916: train D loss: 0.6902, train F loss: -0.6764, acc 0.9960
# epoch 2917: train D loss: 0.6891, train F loss: -0.6693, acc 0.9946
# epoch 2918: train D loss: 0.6912, train F loss: -0.6712, acc 0.9932
# epoch 2919: train D loss: 0.6896, train F loss: -0.6724, acc 0.9942
# epoch 2920: train D loss: 0.6878, train F loss: -0.6742, acc 0.9956
# epoch 2921: train D loss: 0.6888, train F loss: -0.6780, acc 0.9968
# epoch 2922: train D loss: 0.6897, train F loss: -0.6748, acc 0.9950
# epoch 2923: train D loss: 0.6886, train F loss: -0.6770, acc 0.9960
# epoch 2924: train D loss: 0.6880, train F loss: -0.6683, acc 0.9948
# epoch 2925: train D loss: 0.6874, train F loss: -0.6750, acc 0.9958
# epoch 2926: train D loss: 0.6892, train F loss: -0.6750, acc 0.9964
# epoch 2927: train D loss: 0.6886, train F loss: -0.6721, acc 0.9942
# epoch 2928: train D loss: 0.6893, train F loss: -0.6762, acc 0.9950
# epoch 2929: train D loss: 0.6900, train F loss: -0.6741, acc 0.9948
# epoch 2930: train D loss: 0.6903, train F loss: -0.6737, acc 0.9962
# epoch 2931: train D loss: 0.6903, train F loss: -0.6683, acc 0.9930
# epoch 2932: train D loss: 0.6890, train F loss: -0.6759, acc 0.9952
# epoch 2933: train D loss: 0.6865, train F loss: -0.6671, acc 0.9950
# epoch 2934: train D loss: 0.6905, train F loss: -0.6753, acc 0.9946
# epoch 2935: train D loss: 0.6852, train F loss: -0.6746, acc 0.9966
# epoch 2936: train D loss: 0.6927, train F loss: -0.6791, acc 0.9958
# epoch 2937: train D loss: 0.6888, train F loss: -0.6777, acc 0.9960
# epoch 2938: train D loss: 0.6899, train F loss: -0.6730, acc 0.9942
# epoch 2939: train D loss: 0.6902, train F loss: -0.6766, acc 0.9956
# epoch 2940: train D loss: 0.6894, train F loss: -0.6742, acc 0.9960
# epoch 2941: train D loss: 0.6888, train F loss: -0.6742, acc 0.9956
# epoch 2942: train D loss: 0.6878, train F loss: -0.6685, acc 0.9936
# epoch 2943: train D loss: 0.6917, train F loss: -0.6800, acc 0.9956
# epoch 2944: train D loss: 0.6891, train F loss: -0.6765, acc 0.9948
# epoch 2945: train D loss: 0.6895, train F loss: -0.6790, acc 0.9962
# epoch 2946: train D loss: 0.6927, train F loss: -0.6763, acc 0.9948
# epoch 2947: train D loss: 0.6867, train F loss: -0.6735, acc 0.9954
# epoch 2948: train D loss: 0.6894, train F loss: -0.6727, acc 0.9948
# epoch 2949: train D loss: 0.6902, train F loss: -0.6791, acc 0.9960
# epoch 2950: train D loss: 0.6864, train F loss: -0.6720, acc 0.9944
# epoch 2951: train D loss: 0.6905, train F loss: -0.6717, acc 0.9952
# epoch 2952: train D loss: 0.6878, train F loss: -0.6739, acc 0.9950
# epoch 2953: train D loss: 0.6884, train F loss: -0.6721, acc 0.9946
# epoch 2954: train D loss: 0.6916, train F loss: -0.6778, acc 0.9950
# epoch 2955: train D loss: 0.6894, train F loss: -0.6759, acc 0.9956
# epoch 2956: train D loss: 0.6903, train F loss: -0.6752, acc 0.9944
# epoch 2957: train D loss: 0.6893, train F loss: -0.6710, acc 0.9942
# epoch 2958: train D loss: 0.6892, train F loss: -0.6703, acc 0.9942
# epoch 2959: train D loss: 0.6876, train F loss: -0.6621, acc 0.9926
# epoch 2960: train D loss: 0.6902, train F loss: -0.6771, acc 0.9956
# epoch 2961: train D loss: 0.6906, train F loss: -0.6793, acc 0.9964
# epoch 2962: train D loss: 0.6871, train F loss: -0.6696, acc 0.9960
# epoch 2963: train D loss: 0.6886, train F loss: -0.6741, acc 0.9938
# epoch 2964: train D loss: 0.6880, train F loss: -0.6735, acc 0.9956
# epoch 2965: train D loss: 0.6884, train F loss: -0.6784, acc 0.9964
# epoch 2966: train D loss: 0.6863, train F loss: -0.6659, acc 0.9962
# epoch 2967: train D loss: 0.6910, train F loss: -0.6781, acc 0.9952
# epoch 2968: train D loss: 0.6862, train F loss: -0.6721, acc 0.9954
# epoch 2969: train D loss: 0.6902, train F loss: -0.6756, acc 0.9948
# epoch 2970: train D loss: 0.6897, train F loss: -0.6702, acc 0.9930
# epoch 2971: train D loss: 0.6896, train F loss: -0.6716, acc 0.9946
# epoch 2972: train D loss: 0.6875, train F loss: -0.6769, acc 0.9970
# epoch 2973: train D loss: 0.6880, train F loss: -0.6697, acc 0.9942
# epoch 2974: train D loss: 0.6912, train F loss: -0.6789, acc 0.9958
# epoch 2975: train D loss: 0.6899, train F loss: -0.6715, acc 0.9938
# epoch 2976: train D loss: 0.6886, train F loss: -0.6755, acc 0.9954
# epoch 2977: train D loss: 0.6903, train F loss: -0.6787, acc 0.9964
# epoch 2978: train D loss: 0.6890, train F loss: -0.6754, acc 0.9954
# epoch 2979: train D loss: 0.6874, train F loss: -0.6732, acc 0.9938
# epoch 2980: train D loss: 0.6896, train F loss: -0.6751, acc 0.9958
# epoch 2981: train D loss: 0.6912, train F loss: -0.6711, acc 0.9942
# epoch 2982: train D loss: 0.6891, train F loss: -0.6766, acc 0.9956
# epoch 2983: train D loss: 0.6904, train F loss: -0.6691, acc 0.9930
# epoch 2984: train D loss: 0.6891, train F loss: -0.6773, acc 0.9964
# epoch 2985: train D loss: 0.6906, train F loss: -0.6758, acc 0.9944
# epoch 2986: train D loss: 0.6910, train F loss: -0.6805, acc 0.9966
# epoch 2987: train D loss: 0.6919, train F loss: -0.6779, acc 0.9956
# epoch 2988: train D loss: 0.6912, train F loss: -0.6726, acc 0.9952
# epoch 2989: train D loss: 0.6891, train F loss: -0.6725, acc 0.9942
# epoch 2990: train D loss: 0.6910, train F loss: -0.6774, acc 0.9952
# epoch 2991: train D loss: 0.6892, train F loss: -0.6708, acc 0.9946
# epoch 2992: train D loss: 0.6905, train F loss: -0.6770, acc 0.9960
# epoch 2993: train D loss: 0.6890, train F loss: -0.6746, acc 0.9956
# epoch 2994: train D loss: 0.6905, train F loss: -0.6729, acc 0.9946
# epoch 2995: train D loss: 0.6898, train F loss: -0.6771, acc 0.9962
# epoch 2996: train D loss: 0.6879, train F loss: -0.6707, acc 0.9954
# epoch 2997: train D loss: 0.6906, train F loss: -0.6727, acc 0.9930
# epoch 2998: train D loss: 0.6877, train F loss: -0.6770, acc 0.9964
# epoch 2999: train D loss: 0.6870, train F loss: -0.6726, acc 0.9952

# %% [markdown]
# # Inference
#
# We use pandas to generate our csv file.
#
# BTW, the performance of the model trained for 200 epoches might be unstable. You can train for more epoches for a more stable performance.

# %%
result = []
feature_extractor = FeatureExtractor().cuda()
label_predictor = LabelPredictor().cuda()
feature_extractor.load_state_dict(torch.load(f"/content/drive/MyDrive/DaNN/extractor_model.bin"))
label_predictor.load_state_dict(torch.load(f"/content/drive/MyDrive/DaNN/predictor_model.bin"))
label_predictor.eval()
feature_extractor.eval()
for i, (test_data, _) in enumerate(test_dataloader):
    test_data = test_data.cuda()

    class_logits = label_predictor(feature_extractor(test_data))

    x = torch.argmax(class_logits, dim=1).cpu().detach().numpy()
    result.append(x)

import pandas as pd
result = np.concatenate(result)

# Generate your submission
df = pd.DataFrame({'id': np.arange(0,len(result)), 'label': result})
df.to_csv('/content/drive/MyDrive/DaNN/DaNN_submission.csv',index=False)

# %% [markdown]
# # Visualization
# We use t-SNE plot to observe the distribution of extracted features.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold

# %% [markdown]
# ## Step1: Load checkpoint and evaluate to get extracted features

# %%
# Hints:
# Set features_extractor to eval mode
# Start evaluation and collect features and labels
def visual(num):
    feature_extractor = FeatureExtractor().cuda()
    feature_extractor.load_state_dict(torch.load(f"/content/drive/MyDrive/DaNN/extractor_model_{num}.bin"))
    feature_extractor.eval()

    source_dataset = ImageFolder('real_or_drawing/train_data', transform=source_transform)
    source_dataloader = DataLoader(source_dataset, batch_size=1, shuffle=True)
    target_dataset = ImageFolder('real_or_drawing/test_data', transform=target_transform)
    target_dataloader = DataLoader(target_dataset, batch_size=1, shuffle=True)

    labels = []
    X = []
    for i, (test_data, lb) in enumerate(source_dataloader):
        test_data = test_data.cuda()
        feature = feature_extractor(test_data)
        labels.append(int(lb.cpu().detach()))
        X.append(feature.cpu().detach().numpy())
    X = np.array(X)

    # process extracted features with t-SNE
    X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(X)

    # Normalization the processed features 
    x_min, x_max = X_tsne.min(0), X_tsne.max(0)
    X_norm = (X_tsne - x_min) / (x_max - x_min)

    plt.figure(figsize=(10,10))
    plt.scatter(X_norm[:, 0], X_norm[:, 1], c=labels, s=0.5)
    plt.axis('off') 
    plt.show()

    labels = []
    X = []
    for i, (test_data, _) in enumerate(source_dataloader):
        test_data = test_data.cuda()
        feature = feature_extractor(test_data)
        labels.append(1)
        X.append(feature.cpu().detach().numpy())

    for i, (test_data, _) in enumerate(target_dataloader):
        if i >= 5000:
            break
        test_data = test_data.cuda()
        feature = feature_extractor(test_data)
        labels.append(0)
        X.append(feature.cpu().detach().numpy())
    X = np.array(X)


    # process extracted features with t-SNE
    X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(X)

    # Normalization the processed features 
    x_min, x_max = X_tsne.min(0), X_tsne.max(0)
    X_norm = (X_tsne - x_min) / (x_max - x_min)

    plt.figure(figsize=(10,10))
    plt.scatter(X_norm[:, 0], X_norm[:, 1], c=labels, s=0.5)
    plt.axis('off') 
    plt.show()

# %%
labels = []
X = []
for i, (test_data, _) in enumerate(source_dataloader):
    test_data = test_data.cuda()
    feature = feature_extractor(test_data)
    labels.append(1)
    X.append(feature.cpu().detach().numpy())

for i, (test_data, _) in enumerate(target_dataloader):
    if i >= 5000:
        break
    test_data = test_data.cuda()
    feature = feature_extractor(test_data)
    labels.append(0)
    X.append(feature.cpu().detach().numpy())
X = np.array(X)


# process extracted features with t-SNE
X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(X)

# Normalization the processed features 
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)

plt.figure(figsize=(10,10))
plt.scatter(X_norm[:, 0], X_norm[:, 1], c=labels, s=0.5)
plt.axis('off') 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10001 samples in 0.004s...
# [t-SNE] Computed neighbors for 10001 samples in 2.721s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10001
# [t-SNE] Computed conditional probabilities for sample 2000 / 10001
# [t-SNE] Computed conditional probabilities for sample 3000 / 10001
# [t-SNE] Computed conditional probabilities for sample 4000 / 10001
# [t-SNE] Computed conditional probabilities for sample 5000 / 10001
# [t-SNE] Computed conditional probabilities for sample 6000 / 10001
# [t-SNE] Computed conditional probabilities for sample 7000 / 10001
# [t-SNE] Computed conditional probabilities for sample 8000 / 10001
# [t-SNE] Computed conditional probabilities for sample 9000 / 10001
# [t-SNE] Computed conditional probabilities for sample 10000 / 10001
# [t-SNE] Computed conditional probabilities for sample 10001 / 10001
# [t-SNE] Mean sigma: 1.499904
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.041115
# [t-SNE] KL divergence after 1000 iterations: 2.277110

# %% [markdown]
# # Training Statistics
#
# - Number of parameters:
#   - Feature Extractor: 2, 142, 336
#   - Label Predictor: 530, 442
#   - Domain Classifier: 1, 055, 233
#
# - Simple
#  - Training time on colab: ~ 1 hr
# - Medium
#  - Training time on colab: 2 ~ 4 hr
# - Strong
#  - Training time on colab: 5 ~ 6 hrs
# - Boss
#  - **Unmeasurable**

# %% [markdown]
# # Learning Curve (Strong Baseline)
# * This method is slightly different from colab.
#
# ![Loss Curve](https://i.imgur.com/vIujQyo.png)
#
# # Accuracy Curve (Strong Baseline)
# * Note that you cannot access testing accuracy. But this plot tells you that even though the model overfits the training data, the testing accuracy is still improving, and that's why you need to train more epochs.
#
# ![Acc Curve](https://i.imgur.com/4W1otXG.png)

# %% [markdown]
# # Q&A
#
# If there is any problem related to Domain Adaptation, please email to b08901058@ntu.edu.tw / mlta-2022-spring@googlegroups.com。

# %%
for i in [500, 1000, 1500, 2000]:
    print(i)
    visual(i)
# Out:
# 500
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 0.777s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.878979
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.935219
# [t-SNE] KL divergence after 1000 iterations: 1.503554
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.004s...
# [t-SNE] Computed neighbors for 10000 samples in 2.901s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.668445
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.964920
# [t-SNE] KL divergence after 1000 iterations: 2.017731
# 1000
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 0.768s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.879037
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.689735
# [t-SNE] KL divergence after 1000 iterations: 1.453518
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.004s...
# [t-SNE] Computed neighbors for 10000 samples in 2.852s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.791859
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.112762
# [t-SNE] KL divergence after 1000 iterations: 1.936486
# 1500
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 0.790s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 2.070888
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.168015
# [t-SNE] KL divergence after 1000 iterations: 1.346750
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.004s...
# [t-SNE] Computed neighbors for 10000 samples in 2.909s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.899977
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.004112
# [t-SNE] KL divergence after 1000 iterations: 1.807870
# 2000
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 0.827s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 2.101777
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.205338
# [t-SNE] KL divergence after 1000 iterations: 1.280675
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.004s...
# [t-SNE] Computed neighbors for 10000 samples in 3.004s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.893901
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.464272
# [t-SNE] KL divergence after 1000 iterations: 1.785671

# %%
for i in [500, 1000, 1500, 2000, 2500, 3000]:
    print(i)
    visual(i)
# Out:
# 500
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 0.761s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.741158
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.351204
# [t-SNE] KL divergence after 1000 iterations: 1.527886
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.005s...
# [t-SNE] Computed neighbors for 10000 samples in 2.774s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.594696
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.397812
# [t-SNE] KL divergence after 1000 iterations: 2.066430
# 1000
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 0.749s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.862479
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.657631
# [t-SNE] KL divergence after 1000 iterations: 1.431140
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.004s...
# [t-SNE] Computed neighbors for 10000 samples in 2.670s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.750127
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.549606
# [t-SNE] KL divergence after 1000 iterations: 1.934384
# 1500
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 0.774s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.960620
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.190552
# [t-SNE] KL divergence after 1000 iterations: 1.362856
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.004s...
# [t-SNE] Computed neighbors for 10000 samples in 2.556s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.803289
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.305374
# [t-SNE] KL divergence after 1000 iterations: 1.856312
# 2000
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 0.781s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 2.132394
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.376343
# [t-SNE] KL divergence after 1000 iterations: 1.336725
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.004s...
# [t-SNE] Computed neighbors for 10000 samples in 2.763s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.923697
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.976242
# [t-SNE] KL divergence after 1000 iterations: 1.815977
# 2500
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 0.785s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 2.076501
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.964859
# [t-SNE] KL divergence after 1000 iterations: 1.318176
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.004s...
# [t-SNE] Computed neighbors for 10000 samples in 2.578s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.890294
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.471870
# [t-SNE] KL divergence after 1000 iterations: 1.810375
# 3000
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.002s...
# [t-SNE] Computed neighbors for 5000 samples in 0.788s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 2.050007
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.437920
# [t-SNE] KL divergence after 1000 iterations: 1.306143
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.005s...
# [t-SNE] Computed neighbors for 10000 samples in 2.719s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.905367
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.925812
# [t-SNE] KL divergence after 1000 iterations: 1.755670
